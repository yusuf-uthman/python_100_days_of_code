# %%
import requests
from bs4 import BeautifulSoup
url = 'https://www.labvolution.de/de/suche/?category=ep'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'lxml')
soup2 = BeautifulSoup(response.text, 'html.parser')
print(soup)
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="DE" prefix="og: http://ogp.me/ns#">
# <head>
# <meta charset="utf-8"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <title>Suche</title>
# <meta name="description"/>
# <meta content="DE" name="sprache"/>
# <meta name="keywords"/>
# <meta name="tags"/>
# <meta name="tag-synonyms"/>
# <meta content="Suche" name="headline"/>
# <meta name="primaryTagId"/>
# <meta name="primaryTagInterestId"/>
# <meta content="Artikel" name="meldungsart"/>
# <meta content="/files/files/079/media/bilder/applikation/teaser-application-pages/kundenbereich_3_2_tablet_706_470.jpg" name="teaserImage"/>
# <meta name="navParent"/>
# <meta content="width=device-width, initial-scale=1.0, minimum-scale=1.0, user-scalable=no" name="viewport"/>
# <meta name="media:xs"/>
# <meta name="media:sm"/>
# <meta name="media:md"/>
# <meta name="media:lg"/>
# <meta name="media:xl"/>
# <meta name="media:small"/>
# <meta name="media:medium"/>
# <meta name="media:large"/>
# <meta name="media:xlarge"/>
# <meta name="media:xxlarge"/>
# <meta content="labvolution" name="application-name"/>
# <meta content="#FFFFFF" name="msapplication-TileColor"/>
# <meta content="/files/files/assets/v3.34.3/assets/static/labvolution/meta/mstile-70x70-labvolution.png" name="msapplication-TileImage"/>
# <meta content="/files/files/assets/v3.34.3/assets/static/labvolution/meta/mstile-70x70-labvolution.png" name="msapplication-square70x70logo"/>
# <meta content="/files/files/assets/v3.34.3/assets/static/labvolution/meta/mstile-150x150-labvolution.png" name="msapplication-square150x150logo"/>
# <meta content="/files/files/assets/v3.34.3/assets/static/labvolution/meta/mstile-310x150-labvolution.png" name="msapplication-wide310x150logo"/>
# <meta content="/files/files/assets/v3.34.3/assets/static/labvolution/meta/mstile-310x310-labvolution.png" name="msapplication-square310x310logo"/>
# <meta content="yes" name="apple-mobile-web-app-capable"/>
# <meta content="black" name="apple-mobile-web-app-status-bar-style"/>
# <meta content="website" property="og:type"/>
# <meta content="https://www.labvolution.de" property="og:site_name"/>
# <meta content="https://www.labvolution.de/de/suche/" property="og:url"/>
# <meta property="og:title"/>
# <meta property="og:description"/>
# <meta content="/files/files/assets/v3.34.3/assets/static/labvolution/meta/og-labvolution.jpg" property="og:image"/>
# <meta content="1200" property="og:image:width"/>
# <meta content="630" property="og:image:height"/>
# <meta property="twitter:site"/>
# <meta content="summary_large_image" property="twitter:card"/>
# <link href="https://www.labvolution.de/de/suche/" rel="canonical"/>
# <link href="/files/files/assets/v3.34.3/assets/static/labvolution/meta/favicon-labvolution.ico" rel="icon" type="image/x-icon"/>
# <link href="/files/files/assets/v3.34.3/assets/static/labvolution/meta/apple-touch-icon-57x57-labvolution.png" rel="apple-touch-icon-precomposed" sizes="57x57"/>
# <link href="/files/files/assets/v3.34.3/assets/static/labvolution/meta/apple-touch-icon-60x60-labvolution.png" rel="apple-touch-icon-precomposed" sizes="60x60"/>
# <link href="/files/files/assets/v3.34.3/assets/static/labvolution/meta/apple-touch-icon-72x72-labvolution.png" rel="apple-touch-icon-precomposed" sizes="72x72"/>
# <link href="/files/files/assets/v3.34.3/assets/static/labvolution/meta/apple-touch-icon-76x76-labvolution.png" rel="apple-touch-icon-precomposed" sizes="76x76"/>
# <link href="/files/files/assets/v3.34.3/assets/static/labvolution/meta/apple-touch-icon-114x114-labvolution.png" rel="apple-touch-icon-precomposed" sizes="114x114"/>
# <link href="/files/files/assets/v3.34.3/assets/static/labvolution/meta/apple-touch-icon-120x120-labvolution.png" rel="apple-touch-icon-precomposed" sizes="120x120"/>
# <link href="/files/files/assets/v3.34.3/assets/static/labvolution/meta/apple-touch-icon-144x144-labvolution.png" rel="apple-touch-icon-precomposed" sizes="144x144"/>
# <link href="/files/files/assets/v3.34.3/assets/static/labvolution/meta/apple-touch-icon-152x152-labvolution.png" rel="apple-touch-icon-precomposed" sizes="152x152"/>
# <link href="/files/files/assets/v3.34.3/assets/static/labvolution/meta/favicon-16x16-labvolution.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="/files/files/assets/v3.34.3/assets/static/labvolution/meta/favicon-32x32-labvolution.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="/files/files/assets/v3.34.3/assets/static/labvolution/meta/favicon-96x96-labvolution.png" rel="icon" sizes="96x96" type="image/png"/>
# <link href="/files/files/assets/v3.34.3/assets/static/labvolution/meta/favicon-128x128-labvolution.png" rel="icon" sizes="128x128" type="image/png"/>
# <link href="/files/files/assets/v3.34.3/assets/static/labvolution/meta/favicon-196x196-labvolution.png" rel="icon" sizes="196x196" type="image/png"/>
# <link href="/files/files/assets/v3.34.3/assets/css/styles_app_light.css" rel="stylesheet"/>
# <link href="/files/files/assets/v3.34.3/assets/css/styles_labvolution.css" rel="stylesheet"/>
# <style type="text/css">
# 		.adesso-hide-first-divider > section.c.divider { display: none; }
# 		.adesso-hide-first-divider > section.c.divider ~ section.c.divider { display: block; }
# 	</style>
# </head>
# <body class="application-page has-navigation is-labvolution messe-theme-light">
# <!-- Google Tag Manager -->
# <noscript><iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-PLPKMSX" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <script>//<![CDATA[
#
# 	dataLayer = [{
# 		"pageid": "GTM-PLPKMSX"
# 	}];
#
# 	(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({"gtm.start":
# 	new Date().getTime(),event:"gtm.js"});var f=d.getElementsByTagName(s)[0],
# 	j=d.createElement(s),dl=l!="dataLayer"?"&l="+l:"";j.async=true;j.src=
# 	"//www.googletagmanager.com/gtm.js?id="+i+dl;f.parentNode.insertBefore(j,f);
# 	})(window,document,"script","dataLayer","GTM-PLPKMSX");
#
# 	//]]></script>
# <!-- End Google Tag Manager -->
# <script id="application-settings" type="application/json">
# {
# 	"lang": "DE",
# 	"vstJahr": "2019",
# 	"ticketJahr": "2021",
# 	"vstNummer": "079",
# 	"csrf-token": "03f1435d-4e23-4619-a0db-810774db0cd4"
# }
# </script>
# <main id="app">
# <!--index_ignore_begin-->
# <c-navigation-main :visiting="-1" drawer-label="Menü" module-theme="100" superbanner-label="Anzeige" v-cloak="" v-theme="100">
# <template slot="meta-date">
# <a href="/de/ueber-uns/labvolution/">09. - 11. Mai 2023 |  LABVOLUTION</a>
# </template>
# <template slot="meta-date-small">
# <a href="/de/ueber-uns/labvolution/">09. - 11. Mai 2023 | </a>
# </template>
# <template slot="meta-dashboard">
# <a href="/de/applikation/dashboard/merkliste/#popover-login">Merkliste</a>
# </template>
# <template slot="meta-my-messe-not-loggedin">
# <a href="#popover-login" v-link="">Login</a>
# </template>
# <template slot="meta-my-messe">Mein Account</template>
# <template slot="meta-my-messe-dropdown">
# <div class="t set-040-wide as-cat-headline profile">Profil</div>
# <div>
# <a href="/de/applikation/dashboard/profil/">Nutzerkonto</a>
# </div>
# <div>
# <a href="/de/applikation/dashboard/news-service/">News-Service</a>
# </div>
# <c-form-frame action="/de/logout/" class="as-inline is-logout" method="POST" v-cloak="">
# <input name="_csrf" type="hidden" value="03f1435d-4e23-4619-a0db-810774db0cd4"/>
# <button class="item inline" type="submit">Abmelden</button>
# </c-form-frame>
# </template>
# <template slot="meta-logout-button-mobile">
# <c-form-frame action="/de/logout/" class="as-inline is-logout" method="POST" v-cloak="">
# <input name="_csrf" type="hidden" value="03f1435d-4e23-4619-a0db-810774db0cd4"/>
# <button class="hc sub-item" type="submit">
# <div class="sub-item-label t set-250-bold">Abmelden</div>
# </button>
# </c-form-frame>
# </template>
# <template slot="meta-login-mobile">
# <a class="menu-item mobile-menu-login t set-150-bold hide-for-large" href="#popover-login" v-link="">
# <span class="label">Login</span>
# </a>
# </template>
# <template slot="logo">
# <a href="/de/">
# <img src="/files/files/assets/v3.34.3/assets/static/labvolution/logo/logo-light-labvolution.svg"/>
# </a>
# </template>
# <template slot="logo-small">
# <a href="/de/">
# <img src="/files/files/assets/v3.34.3/assets/static/labvolution/logo/logo-light-mobile-labvolution.svg"/>
# </a>
# </template>
# <template slot="search-input">
# <input placeholder="Suchbegriff eingeben..."/>
# </template>
# <template slot="menu">
# <o-navigation-item>
# <a class="visiting" href="/de/ueber-uns/" slot="menu-item">Über LABVOLUTION 2023</a>
# <template slot="submenu-items">
# <a href="/de/ueber-uns/labvolution/">LABVOLUTION 2023</a><a href="/de/ueber-uns/labvolution-award/">LABVOLUTION AWARD</a><a href="/de/ueber-uns/aussteller-produktsuche/">Rückblick Aussteller &amp; Produkte 2019</a><a href="/de/ueber-uns/presse/">Presse</a><a href="/de/ueber-uns/mediathek/index-2">Mediathek</a><a href="/de/ueber-uns/ueber-smartlab-connects/">Über smartLAB connects 2021</a>
# </template>
# </o-navigation-item>
# </template>
# <template slot="other-actions">
# <i class="icon icon-search"></i>
# </template>
# </c-navigation-main>
# <c-navigation-search no-ads="true" superbanner-label="Anzeige" v-cloak="" v-theme="300">
# <div class="grid-x grid-padding-x">
# <div class="cell small-12 medium-10 medium-offset-1 large-6 large-offset-3">
# <c-search-bar action="/de/suche/" auto-suggest="/autocomplete?locale=D&amp;search={s}" autocomplete="off" dimmer="" fixed="" form="" method="POST" module-theme="300" placeholder="Suchbegriff eingeben..." v-cloak="">
# <div class="grid-container">
# <div class="grid-x align-center">
# </div>
# </div>
# </c-search-bar>
# </div>
# </div>
# </c-navigation-search>
# <!--index_ignore_end-->
# <div class="flex-container flex-dir-column fullheight">
# <div class="flex-child-grow">
# <!--index_ignore_begin-->
# <c-search-results action="/de/suche/" button-label="Suche eingrenzen" has-filter-boxes="true" method="POST" v-cloak="" v-theme="100">
# <template slot="header">
# <c-search-header v-cloak="" v-theme="300">
# <template slot="search">
# <c-search-bar auto-suggest="/autocomplete?locale=D&amp;search={s}&amp;rt=EXHIBITOR,PRODUCT" autocomplete="off" mobile-placeholder="Aussteller &amp; Produkte suchen" module-theme="300" placeholder="Neue Suche nach Ausstellern &amp; Produkten" v-cloak="">
# </c-search-bar>
# </template>
# </c-search-header>
# <div class="grid-container">
# <div class="search-results-content-links responsive-margin">
# <a class="t set-040-caps set-caption as-caption icon icon-hamburger" href="/de/ausstellung/ausstellerliste/">
# <span>Zur Ausstellerliste</span>
# </a>
# <a class="t set-040-caps set-caption as-caption icon icon-search" href="/de/ausstellung/produktgruppen/index-2">
# <span>Zum Produktgruppenverzeichnis</span>
# </a>
# </div>
# </div>
# </template>
# <template slot="filter">
# <c-search-filter-singlechoice v-cloak="" v-theme="100">
# <template slot="header">
# <a class="t set-080-regular back-button" data-action="resultCategoryReset" v-reactive-form.click="">
# <i class="icon as-icon-size-small icon-bracket-left"></i>
#                             Alle Kategorien
#                         </a>
# <h3 class="t set-400-bold">Aussteller &amp; Produkte</h3>
# <div class="search-filter-singlechoice-divider">
# <o-divider v-theme="100">
# </o-divider>
# </div>
# </template>
# <template slot="content">
# <c-full-search-filter-box :init-items="3" :items-length="3" headline="Treffertyp" less="Weniger anzeigen" more="Alle anzeigen">
# <template slot="reset">
# </template>
# <template>
# <div>
# <o-form-checkbox data-action="filter" data-class="ht" data-value="Aussteller" v-reactive-form.change="">
# <template slot="label">
# <span class="t set-080-regular">Aussteller</span>
# <span class="filter-results">(290)</span>
# </template>
# </o-form-checkbox>
# </div>
# <div>
# <o-form-checkbox data-action="filter" data-class="ht" data-value="Produkt" v-reactive-form.change="">
# <template slot="label">
# <span class="t set-080-regular">Produkte</span>
# <span class="filter-results">(881)</span>
# </template>
# </o-form-checkbox>
# </div>
# <div>
# <o-form-checkbox data-action="filter" data-class="ht" data-value="Sonderpräsentation" v-reactive-form.change="">
# <template slot="label">
# <span class="t set-080-regular">Sonderpräsentationen</span>
# <span class="filter-results">(1)</span>
# </template>
# </o-form-checkbox>
# </div>
# </template>
# </c-full-search-filter-box><c-full-search-filter-box :init-items="3" :items-length="2" headline="Neuheiten" less="Weniger anzeigen" more="Alle anzeigen">
# <template slot="reset">
# </template>
# <template>
# <div>
# <o-form-checkbox data-action="filter" data-class="pt" data-value="FE-Projekt" v-reactive-form.change="">
# <template slot="label">
# <span class="t set-080-regular">F&amp;E-Projekte</span>
# <span class="filter-results">(13)</span>
# </template>
# </o-form-checkbox>
# </div>
# <div>
# <o-form-checkbox data-action="filter" data-class="pt" data-value="Messepremiere" v-reactive-form.change="">
# <template slot="label">
# <span class="t set-080-regular">Messepremieren</span>
# <span class="filter-results">(131)</span>
# </template>
# </o-form-checkbox>
# </div>
# </template>
# </c-full-search-filter-box><c-full-search-filter-box :init-items="3" :items-length="9" headline="Produktgruppen" less="Weniger anzeigen" more="Alle anzeigen">
# <template slot="reset">
# </template>
# <template>
# <div>
# <a class="t set-100-regular filter-item" data-action="filter" data-class="pg" data-value="531781" v-reactive-form.click="">
#
# 						Analytik
# 						<span class="filter-results">(323)</span>
# </a>
# </div>
# <div>
# <a class="t set-100-regular filter-item" data-action="filter" data-class="pg" data-value="531835" v-reactive-form.click="">
#
# 						Anwendungen in der Biotechnologie
# 						<span class="filter-results">(379)</span>
# </a>
# </div>
# <div>
# <a class="t set-100-regular filter-item" data-action="filter" data-class="pg" data-value="531823" v-reactive-form.click="">
#
# 						Anwendungen und Verfahren
# 						<span class="filter-results">(111)</span>
# </a>
# </div>
# <div class="hidden">
# <a class="t set-100-regular filter-item" data-action="filter" data-class="pg" data-value="531818" v-reactive-form.click="">
#
# 						Chemikalien, Reagenzien, Bedarfs- und Verbrauchsartikel
# 						<span class="filter-results">(156)</span>
# </a>
# </div>
# <div class="hidden">
# <a class="t set-100-regular filter-item" data-action="filter" data-class="pg" data-value="531897" v-reactive-form.click="">
#
# 						Fachbezogene Dienstleistungen
# 						<span class="filter-results">(22)</span>
# </a>
# </div>
# <div class="hidden">
# <a class="t set-100-regular filter-item" data-action="filter" data-class="pg" data-value="531883" v-reactive-form.click="">
#
# 						Forschungsinstitute, Universitäten, Hochschulen und Karriere
# 						<span class="filter-results">(52)</span>
# </a>
# </div>
# <div class="hidden">
# <a class="t set-100-regular filter-item" data-action="filter" data-class="pg" data-value="531801" v-reactive-form.click="">
#
# 						Informatik, Digitalisierung, Big Data
# 						<span class="filter-results">(93)</span>
# </a>
# </div>
# <div class="hidden">
# <a class="t set-100-regular filter-item" data-action="filter" data-class="pg" data-value="531755" v-reactive-form.click="">
#
# 						Labortechnik und -infrastruktur, Laborautomation
# 						<span class="filter-results">(628)</span>
# </a>
# </div>
# <div class="hidden">
# <a class="t set-100-regular filter-item" data-action="filter" data-class="pg" data-value="531891" v-reactive-form.click="">
#
# 						Verbände und Institutionen
# 						<span class="filter-results">(10)</span>
# </a>
# </div>
# </template>
# </c-full-search-filter-box><c-full-search-filter-box :init-items="3" :items-length="17" headline="Anwendungsbereiche" less="Weniger anzeigen" more="Alle anzeigen">
# <template slot="reset">
# </template>
# <template>
# <div>
# <a class="t set-100-regular filter-item" data-action="filter" data-class="zb" data-value="1501" v-reactive-form.click="">
#
# 						Alle Branchen, branchenunabhängig
# 						<span class="filter-results">(14)</span>
# </a>
# </div>
# <div>
# <a class="t set-100-regular filter-item" data-action="filter" data-class="zb" data-value="1298" v-reactive-form.click="">
#
# 						Behörden &amp; Öffentliche Dienste
# 						<span class="filter-results">(2)</span>
# </a>
# </div>
# <div>
# <a class="t set-100-regular filter-item" data-action="filter" data-class="zb" data-value="1220" v-reactive-form.click="">
#
# 						Bergbau und Gewinnung von Steinen und Erden
# 						<span class="filter-results">(5)</span>
# </a>
# </div>
# <div class="hidden">
# <a class="t set-100-regular filter-item" data-action="filter" data-class="zb" data-value="1104" v-reactive-form.click="">
#
# 						Energieversorgung
# 						<span class="filter-results">(10)</span>
# </a>
# </div>
# <div class="hidden">
# <a class="t set-100-regular filter-item" data-action="filter" data-class="zb" data-value="1108" v-reactive-form.click="">
#
# 						Entsorgung &amp; Recycling
# 						<span class="filter-results">(7)</span>
# </a>
# </div>
# <div class="hidden">
# <a class="t set-100-regular filter-item" data-action="filter" data-class="zb" data-value="1411" v-reactive-form.click="">
#
# 						Erbringung von freiberuflichen, wissenschaftlichen und technischen Dienstleistungen
# 						<span class="filter-results">(16)</span>
# </a>
# </div>
# <div class="hidden">
# <a class="t set-100-regular filter-item" data-action="filter" data-class="zb" data-value="1275" v-reactive-form.click="">
#
# 						Erbringung von sonstigen wirtschaftlichen Dienstleistungen
# 						<span class="filter-results">(10)</span>
# </a>
# </div>
# <div class="hidden">
# <a class="t set-100-regular filter-item" data-action="filter" data-class="zb" data-value="1307" v-reactive-form.click="">
#
# 						Erziehung und Unterricht
# 						<span class="filter-results">(5)</span>
# </a>
# </div>
# <div class="hidden">
# <a class="t set-100-regular filter-item" data-action="filter" data-class="zb" data-value="1423" v-reactive-form.click="">
#
# 						Forschung und Entwicklung
# 						<span class="filter-results">(62)</span>
# </a>
# </div>
# <div class="hidden">
# <a class="t set-100-regular filter-item" data-action="filter" data-class="zb" data-value="1371" v-reactive-form.click="">
#
# 						Gastgewerbe/Beherbergung und Gastronomie
# 						<span class="filter-results">(2)</span>
# </a>
# </div>
# <div class="hidden">
# <a class="t set-100-regular filter-item" data-action="filter" data-class="zb" data-value="1314" v-reactive-form.click="">
#
# 						Gesundheits- und Sozialwesen
# 						<span class="filter-results">(38)</span>
# </a>
# </div>
# <div class="hidden">
# <a class="t set-100-regular filter-item" data-action="filter" data-class="zb" data-value="1126" v-reactive-form.click="">
#
# 						Handel; Instandhaltung und Reparatur von Kraftfahrzeugen
# 						<span class="filter-results">(9)</span>
# </a>
# </div>
# <div class="hidden">
# <a class="t set-100-regular filter-item" data-action="filter" data-class="zb" data-value="1381" v-reactive-form.click="">
#
# 						Information und Kommunikation
# 						<span class="filter-results">(3)</span>
# </a>
# </div>
# <div class="hidden">
# <a class="t set-100-regular filter-item" data-action="filter" data-class="zb" data-value="1327" v-reactive-form.click="">
#
# 						Kunst, Unterhaltung und Erholung
# 						<span class="filter-results">(2)</span>
# </a>
# </div>
# <div class="hidden">
# <a class="t set-100-regular filter-item" data-action="filter" data-class="zb" data-value="1203" v-reactive-form.click="">
#
# 						Land- und Forstwirtschaft, Fischerei
# 						<span class="filter-results">(4)</span>
# </a>
# </div>
# <div class="hidden">
# <a class="t set-100-regular filter-item" data-action="filter" data-class="zb" data-value="1781" v-reactive-form.click="">
#
# 						Schüler, Studenten
# 						<span class="filter-results">(6)</span>
# </a>
# </div>
# <div class="hidden">
# <a class="t set-100-regular filter-item" data-action="filter" data-class="zb" data-value="1237" v-reactive-form.click="">
#
# 						Verarbeitendes Gewerbe/Produktion
# 						<span class="filter-results">(78)</span>
# </a>
# </div>
# </template>
# </c-full-search-filter-box><c-full-search-filter-box :init-items="3" :items-length="8" headline="Herkunft" less="Weniger anzeigen" more="Alle anzeigen">
# <template slot="reset">
# </template>
# <template>
# <div>
# <a class="t set-100-regular filter-item" data-action="filter" data-class="or" data-value="101" v-reactive-form.click="">
#
# 						EU - Länder
# 						<span class="filter-results">(962)</span>
# </a>
# </div>
# <div>
# <a class="t set-100-regular filter-item" data-action="filter" data-class="or" data-value="301" v-reactive-form.click="">
#
# 						Nordamerika
# 						<span class="filter-results">(23)</span>
# </a>
# </div>
# <div>
# <a class="t set-100-regular filter-item" data-action="filter" data-class="or" data-value="402" v-reactive-form.click="">
#
# 						Ostasien
# 						<span class="filter-results">(135)</span>
# </a>
# </div>
# <div class="hidden">
# <a class="t set-100-regular filter-item" data-action="filter" data-class="or" data-value="111" v-reactive-form.click="">
#
# 						Sonst.europ. Länder (ohne EU)
# 						<span class="filter-results">(52)</span>
# </a>
# </div>
# </template>
# </c-full-search-filter-box>
# </template>
# </c-search-filter-singlechoice>
# </template>
# <div class="grid-x search-results-select">
# <div class="cell medium-9 number-of-results">
# <h3 class="t set-400-bold as-headline">
# <span>1.172</span>
# <span>Treffer</span>
# </h3>
# </div>
# <div class="cell medium-3">
# <o-form-select :is-floating-label="false" :items='[{"value":"bAZ","label":"A-Z"},{"value":"RANKING","label":"Relevanz"}]' class="not-boxed" data-action="sort" fullwidth="" label="Sortieren nach" v-reactive-form.change="" value="bAZ">
# </o-form-select>
# </div>
# </div>
# <c-search-snippet-list v-cloak="" v-theme="100">
# <template slot="content">
# <div class="cell small-12">
# <o-search-snippet :divider="true" :image-src='["https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A921694/LOG_MO0_21526_38566_155386041881616600_aeid_60__73_atomfeld_60_73-1314141553860464.jpg.png","https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A921694/LOG_TA0_21526_38566_155386041881616600_aeid_60__73_atomfeld_60_73-1314141553860464.jpg.png","https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A921694/LOG_DE0_21526_38566_155386041881616600_aeid_60__73_atomfeld_60_73-1314141553860464.jpg.png"]' href="/aussteller/abbott-informatics-germany/N1404331" image-large-bordered="" label-bookmark="Merken" label-bookmarked="Gemerkt" type="Aussteller 2019" url-bookmark="/api/remember/AU_20174677" v-theme="100">
# <template slot="headline">
# <h2 class="t set-300-bold as-headline search-snippet-name">Abbott Informatics Germany</h2>
# <h3 class="t set-040-wide as-copy search-snippet-attribute">Witten - DE</h3>
# </template>
# <template slot="content">
# <p class="t set-200-regular as-copy search-snippet-description">Mit der Erfahrung von mehr als 30 Jahren in der Laborinformatikbranche unterstützt Abbott Informatics mit seiner STARLIMS Lösung Unternehmen bei der ...</p>
# <div class="search-snippet-additional-detail">
# <div class="search-snippet-additional-detail-flex">
# <p class="t set-100-regular as-copy search-snippet-location"></p>
# </div>
# </div>
# </template>
# </o-search-snippet>
# </div>
# <div class="cell small-12">
# <o-search-snippet :divider="true" :image-src='["https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A921695/LOG_MO0_921695_01813358.jpg.png","https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A921695/LOG_TA0_921695_01813358.jpg.png","https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A921695/LOG_DE0_921695_01813358.jpg.png"]' href="/aussteller/abdos-labtech/E765861" image-large-bordered="" label-bookmark="Merken" label-bookmarked="Gemerkt" type="Aussteller 2019" url-bookmark="/api/remember/AU_10179634" v-theme="100">
# <template slot="headline">
# <h2 class="t set-300-bold as-headline search-snippet-name">Abdos Labtech</h2>
# <h3 class="t set-040-wide as-copy search-snippet-attribute">New Delhi 110025 - IN</h3>
# </template>
# <template slot="content">
# <div class="search-snippet-additional-detail">
# <div class="search-snippet-additional-detail-flex">
# <p class="t set-100-regular as-copy search-snippet-location"></p>
# </div>
# </div>
# </template>
# </o-search-snippet>
# </div>
# <div class="cell small-12">
# <o-search-snippet :divider="true" :image-src='["https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A921696/LOG_MO0_21526_38566_155662867981783800_aeid_60__73_atomfeld_60_73-1314161556628780.png.png","https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A921696/LOG_TA0_21526_38566_155662867981783800_aeid_60__73_atomfeld_60_73-1314161556628780.png.png","https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A921696/LOG_DE0_21526_38566_155662867981783800_aeid_60__73_atomfeld_60_73-1314161556628780.png.png"]' href="/aussteller/absource-diagnostics/N1404332" image-large-bordered="" label-bookmark="Merken" label-bookmarked="Gemerkt" type="Aussteller 2019" url-bookmark="/api/remember/AU_10182540" v-theme="100">
# <template slot="headline">
# <h2 class="t set-300-bold as-headline search-snippet-name">ABSOURCE Diagnostics</h2>
# <h3 class="t set-040-wide as-copy search-snippet-attribute">München - DE</h3>
# </template>
# <template slot="content">
# <p class="t set-200-regular as-copy search-snippet-description">Absource Diagnostics ist der Ansprechpartner Ihrer Wahl, wenn Sie effiziente hochqualitative Laborreagenzien zu fairen Preisen suchen.</p>
# <div class="search-snippet-additional-detail">
# <div class="search-snippet-additional-detail-flex">
# <p class="t set-100-regular as-copy search-snippet-location"></p>
# </div>
# </div>
# </template>
# </o-search-snippet>
# </div>
# <div class="cell small-12">
# <o-search-snippet :divider="true" :image-src='["https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A921697/LOG_MO0_f37dd3cd-2bb3-499f-86bc-0b18e4d913f0_aeid_60__73_atomfeld_60_73-1314171554280181.jpg.png","https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A921697/LOG_TA0_f37dd3cd-2bb3-499f-86bc-0b18e4d913f0_aeid_60__73_atomfeld_60_73-1314171554280181.jpg.png","https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A921697/LOG_DE0_f37dd3cd-2bb3-499f-86bc-0b18e4d913f0_aeid_60__73_atomfeld_60_73-1314171554280181.jpg.png"]' href="/aussteller/academics/V830521" image-large-bordered="" label-bookmark="Merken" label-bookmarked="Gemerkt" type="Aussteller 2019" url-bookmark="/api/remember/AU_10178212" v-theme="100">
# <template slot="headline">
# <h2 class="t set-300-bold as-headline search-snippet-name">academics</h2>
# <h3 class="t set-040-wide as-copy search-snippet-attribute">Hamburg - DE</h3>
# </template>
# <template slot="content">
# <p class="t set-200-regular as-copy search-snippet-description">academics ist der führende Stellenmarkt und Karrierebegleiter aus der ZEIT-Verlagsgruppe. Der Stellenmarkt bietet für alle, die Lust auf Wissenschaft und ...</p>
# <div class="search-snippet-additional-detail">
# <div class="search-snippet-additional-detail-flex">
# <p class="t set-100-regular as-copy search-snippet-location"></p>
# </div>
# </div>
# </template>
# </o-search-snippet>
# </div>
# <div class="cell small-12">
# <o-search-snippet :divider="true" :image-src='["https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A921698/LOG_MO0_21526_38566_155175837173356000_aeid_60__73_atomfeld_60_73-1314181551758420.png.png","https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A921698/LOG_TA0_21526_38566_155175837173356000_aeid_60__73_atomfeld_60_73-1314181551758420.png.png","https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A921698/LOG_DE0_21526_38566_155175837173356000_aeid_60__73_atomfeld_60_73-1314181551758420.png.png"]' href="/aussteller/accubiomed/003594" image-large-bordered="" label-bookmark="Merken" label-bookmarked="Gemerkt" type="Aussteller 2019" url-bookmark="/api/remember/AU_10180296" v-theme="100">
# <template slot="headline">
# <h2 class="t set-300-bold as-headline search-snippet-name">AccuBioMed</h2>
# <h3 class="t set-040-wide as-copy search-snippet-attribute">New Taipei City - TW</h3>
# </template>
# <template slot="content">
# <div class="search-snippet-additional-detail">
# <div class="search-snippet-additional-detail-flex">
# <p class="t set-100-regular as-copy search-snippet-location"></p>
# </div>
# </div>
# </template>
# </o-search-snippet>
# </div>
# <div class="cell small-12">
# <o-search-snippet :divider="true" :image-src='["https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A921699/LOG_MO0_921699_01813376.jpg.png","https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A921699/LOG_TA0_921699_01813376.jpg.png","https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A921699/LOG_DE0_921699_01813376.jpg.png"]' href="/aussteller/advanced-microfluidics/G181010" image-large-bordered="" label-bookmark="Merken" label-bookmarked="Gemerkt" type="Aussteller 2019" url-bookmark="/api/remember/AU_10182501" v-theme="100">
# <template slot="headline">
# <h2 class="t set-300-bold as-headline search-snippet-name">Advanced Microfluidics</h2>
# <h3 class="t set-040-wide as-copy search-snippet-attribute">Ecublens - CH</h3>
# </template>
# <template slot="content">
# <div class="search-snippet-additional-detail">
# <div class="search-snippet-additional-detail-flex">
# <p class="t set-100-regular as-copy search-snippet-location"></p>
# </div>
# </div>
# </template>
# </o-search-snippet>
# </div>
# <div class="cell small-12">
# <o-search-snippet :divider="true" :image-src='["https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A926234/LOG_MO0_926234_01838235.jpg.png","https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A926234/LOG_TA0_926234_01838235.jpg.png","https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A926234/LOG_DE0_926234_01838235.jpg.png"]' href="/aussteller/aicos-technologies/P636533" image-large-bordered="" label-bookmark="Merken" label-bookmarked="Gemerkt" type="Aussteller 2019" url-bookmark="/api/remember/AU_10182927" v-theme="100">
# <template slot="headline">
# <h2 class="t set-300-bold as-headline search-snippet-name">AICOS Technologies</h2>
# <h3 class="t set-040-wide as-copy search-snippet-attribute">Allschwil - CH</h3>
# </template>
# <template slot="content">
# <p class="t set-200-regular as-copy search-snippet-description">AICOS Technologies bietet Beratungsdienstleistungen und spezialisierte Software, die auf die Bedürfnisse der Prozessindustrie zugeschnitten sind, in ...</p>
# <div class="search-snippet-additional-detail">
# <div class="search-snippet-additional-detail-flex">
# <p class="t set-100-regular as-copy search-snippet-location"></p>
# </div>
# </div>
# </template>
# </o-search-snippet>
# </div>
# <div class="cell small-12">
# <o-search-snippet :divider="true" :image-src='["https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A921700/LOG_MO0_921700_01813391.jpg.png","https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A921700/LOG_TA0_921700_01813391.jpg.png","https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A921700/LOG_DE0_921700_01813391.jpg.png"]' href="/aussteller/analytik-jena/K637471" image-large-bordered="" label-bookmark="Merken" label-bookmarked="Gemerkt" type="Aussteller 2019" url-bookmark="/api/remember/AU_10177830" v-theme="100">
# <template slot="headline">
# <h2 class="t set-300-bold as-headline search-snippet-name">Analytik Jena</h2>
# <h3 class="t set-040-wide as-copy search-snippet-attribute">Jena - DE</h3>
# </template>
# <template slot="content">
# <p class="t set-200-regular as-copy search-snippet-description">Die Analytik Jena ist ein führender Anbieter von High-End-Analysemesstechnik, Instrumenten und Produkten im Bereich der Biotechnologie und der molekularen ...</p>
# <div class="search-snippet-additional-detail">
# <div class="search-snippet-additional-detail-flex">
# <p class="t set-100-regular as-copy search-snippet-location"></p>
# </div>
# </div>
# </template>
# </o-search-snippet>
# </div>
# <div class="cell small-12">
# <o-search-snippet :divider="true" :image-src='["https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A921757/LOG_MO0_21526_38566_155067699819858500_aeid_60__73_atomfeld_60_73-1314761550677424.jpg.png","https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A921757/LOG_TA0_21526_38566_155067699819858500_aeid_60__73_atomfeld_60_73-1314761550677424.jpg.png","https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A921757/LOG_DE0_21526_38566_155067699819858500_aeid_60__73_atomfeld_60_73-1314761550677424.jpg.png"]' href="/aussteller/analytik-news/N1404362" image-large-bordered="" label-bookmark="Merken" label-bookmarked="Gemerkt" type="Aussteller 2019" url-bookmark="/api/remember/AU_10182401" v-theme="100">
# <template slot="headline">
# <h2 class="t set-300-bold as-headline search-snippet-name">Analytik NEWS</h2>
# <h3 class="t set-040-wide as-copy search-snippet-attribute">Ober-Ramstadt - DE</h3>
# </template>
# <template slot="content">
# <p class="t set-200-regular as-copy search-snippet-description">Analytik NEWS ist ein unabhängiges Online-Labormagazin, das bereits seit 1998 tagesaktuelle, redaktionell geprüfte Informationen für Labor, Analytik, ...</p>
# <div class="search-snippet-additional-detail">
# <div class="search-snippet-additional-detail-flex">
# <p class="t set-100-regular as-copy search-snippet-location"></p>
# </div>
# </div>
# </template>
# </o-search-snippet>
# </div>
# <div class="cell small-12">
# <o-search-snippet :divider="true" :image-src='["https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A921702/LOG_MO0_a66d7d0e-1002-4ab2-a0d4-74ced1ca0b97_aeid_60__73_atomfeld_60_73-1314221554559722.jpg.png","https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A921702/LOG_TA0_a66d7d0e-1002-4ab2-a0d4-74ced1ca0b97_aeid_60__73_atomfeld_60_73-1314221554559722.jpg.png","https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A921702/LOG_DE0_a66d7d0e-1002-4ab2-a0d4-74ced1ca0b97_aeid_60__73_atomfeld_60_73-1314221554559722.jpg.png"]' href="/aussteller/andrew-alliance/V885357" image-large-bordered="" label-bookmark="Merken" label-bookmarked="Gemerkt" type="Aussteller 2019" url-bookmark="/api/remember/AU_10176938" v-theme="100">
# <template slot="headline">
# <h2 class="t set-300-bold as-headline search-snippet-name">Andrew Alliance</h2>
# <h3 class="t set-040-wide as-copy search-snippet-attribute">Vernier - CH</h3>
# </template>
# <template slot="content">
# <div class="search-snippet-additional-detail">
# <div class="search-snippet-additional-detail-flex">
# <p class="t set-100-regular as-copy search-snippet-location"></p>
# </div>
# </div>
# </template>
# </o-search-snippet>
# </div>
# <div class="cell small-12">
# <o-search-snippet :divider="true" :image-src='["https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A934561/LOG_MO0_21526_38566_155446869265655800_aeid_60__73_atomfeld_60_73-13142531554468719.png.png","https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A934561/LOG_TA0_21526_38566_155446869265655800_aeid_60__73_atomfeld_60_73-13142531554468719.png.png","https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A934561/LOG_DE0_21526_38566_155446869265655800_aeid_60__73_atomfeld_60_73-13142531554468719.png.png"]' href="/aussteller/anvajo/N1411582" image-large-bordered="" label-bookmark="Merken" label-bookmarked="Gemerkt" type="Aussteller 2019" url-bookmark="/api/remember/AU_19048155" v-theme="100">
# <template slot="headline">
# <h2 class="t set-300-bold as-headline search-snippet-name">anvajo</h2>
# <h3 class="t set-040-wide as-copy search-snippet-attribute">Dresden - DE</h3>
# </template>
# <template slot="content">
# <p class="t set-200-regular as-copy search-snippet-description">Die anvajo GmbH, ein Spin-off-Unternehmen der Technischen Universität Dresden, ist Entwickler und Hersteller von Point-of-Care-Lösungen für die ...</p>
# <div class="search-snippet-additional-detail">
# <div class="search-snippet-additional-detail-flex">
# <p class="t set-100-regular as-copy search-snippet-location"></p>
# </div>
# </div>
# </template>
# </o-search-snippet>
# </div>
# <div class="cell small-12">
# <o-search-snippet :divider="true" :image-src='["https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A921703/LOG_MO0_2b4f6be8-1915-464c-adfd-08f009916097_aeid_60__73_atomfeld_60_73-1314231554719642.png.png","https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A921703/LOG_TA0_2b4f6be8-1915-464c-adfd-08f009916097_aeid_60__73_atomfeld_60_73-1314231554719642.png.png","https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A921703/LOG_DE0_2b4f6be8-1915-464c-adfd-08f009916097_aeid_60__73_atomfeld_60_73-1314231554719642.png.png"]' href="/aussteller/apollo-scientific/L162000" image-large-bordered="" label-bookmark="Merken" label-bookmarked="Gemerkt" type="Aussteller 2019" url-bookmark="/api/remember/AU_10177903" v-theme="100">
# <template slot="headline">
# <h2 class="t set-300-bold as-headline search-snippet-name">Apollo Scientific</h2>
# <h3 class="t set-040-wide as-copy search-snippet-attribute">Stockport SK6 2QR - GB</h3>
# </template>
# <template slot="content">
# <div class="search-snippet-additional-detail">
# <div class="search-snippet-additional-detail-flex">
# <p class="t set-100-regular as-copy search-snippet-location"></p>
# </div>
# </div>
# </template>
# </o-search-snippet>
# </div>
# <div class="cell small-12">
# <o-search-snippet :divider="true" :image-src='["https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A934562/LOG_MO0_21526_38566_155436350964074600_aeid_60__73_atomfeld_60_73-13142541554363561.png.png","https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A934562/LOG_TA0_21526_38566_155436350964074600_aeid_60__73_atomfeld_60_73-13142541554363561.png.png","https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A934562/LOG_DE0_21526_38566_155436350964074600_aeid_60__73_atomfeld_60_73-13142541554363561.png.png"]' href="/aussteller/aquila-biolabs/N1411583" image-large-bordered="" label-bookmark="Merken" label-bookmarked="Gemerkt" type="Aussteller 2019" url-bookmark="/api/remember/AU_19048157" v-theme="100">
# <template slot="headline">
# <h2 class="t set-300-bold as-headline search-snippet-name">aquila biolabs</h2>
# <h3 class="t set-040-wide as-copy search-snippet-attribute">Baesweiler - DE</h3>
# </template>
# <template slot="content">
# <div class="search-snippet-additional-detail">
# <div class="search-snippet-additional-detail-flex">
# <p class="t set-100-regular as-copy search-snippet-location"></p>
# </div>
# </div>
# </template>
# </o-search-snippet>
# </div>
# <div class="cell small-12">
# <o-search-snippet :divider="true" :image-src='["https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A921704/LOG_MO0_21526_38566_155076713339991000_aeid_60__73_atomfeld_60_73-1314241550767901.jpg.png","https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A921704/LOG_TA0_21526_38566_155076713339991000_aeid_60__73_atomfeld_60_73-1314241550767901.jpg.png","https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A921704/LOG_DE0_21526_38566_155076713339991000_aeid_60__73_atomfeld_60_73-1314241550767901.jpg.png"]' href="/aussteller/autoscribe-informatics/003587" image-large-bordered="" label-bookmark="Merken" label-bookmarked="Gemerkt" type="Aussteller 2019" url-bookmark="/api/remember/AU_10179444" v-theme="100">
# <template slot="headline">
# <h2 class="t set-300-bold as-headline search-snippet-name">Autoscribe Informatics</h2>
# <h3 class="t set-040-wide as-copy search-snippet-attribute">Reading RG7 8DA - GB</h3>
# </template>
# <template slot="content">
# <p class="t set-200-regular as-copy search-snippet-description">Unsere branchenführenden Laborinformations-Managementsysteme (LIMS) und Qualitätsmanagementsysteme werden weltweit von Laboren eingesetzt. Dank unserer ...</p>
# <div class="search-snippet-additional-detail">
# <div class="search-snippet-additional-detail-flex">
# <p class="t set-100-regular as-copy search-snippet-location"></p>
# </div>
# </div>
# </template>
# </o-search-snippet>
# </div>
# <div class="cell small-12">
# <o-search-snippet :divider="true" :image-src='["https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A921706/LOG_MO0_921706_01813415.jpg.png","https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A921706/LOG_TA0_921706_01813415.jpg.png","https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A921706/LOG_DE0_921706_01813415.jpg.png"]' href="/aussteller/azure-biosystems/D613959" image-large-bordered="" label-bookmark="Merken" label-bookmarked="Gemerkt" type="Aussteller 2019" url-bookmark="/api/remember/AU_10180047" v-theme="100">
# <template slot="headline">
# <h2 class="t set-300-bold as-headline search-snippet-name">Azure Biosystems</h2>
# <h3 class="t set-040-wide as-copy search-snippet-attribute">Dublin, CA 94568 - USA</h3>
# </template>
# <template slot="content">
# <div class="search-snippet-additional-detail">
# <div class="search-snippet-additional-detail-flex">
# <p class="t set-100-regular as-copy search-snippet-location"></p>
# </div>
# </div>
# </template>
# </o-search-snippet>
# </div>
# <div class="cell small-12">
# <o-search-snippet :divider="true" :image-src='["https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A929036/LOG_MO0_21526_38566_155373740962880000_aeid_60__73_atomfeld_60_73-13142411553737788.jpg.png","https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A929036/LOG_TA0_21526_38566_155373740962880000_aeid_60__73_atomfeld_60_73-13142411553737788.jpg.png","https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A929036/LOG_DE0_21526_38566_155373740962880000_aeid_60__73_atomfeld_60_73-13142411553737788.jpg.png"]' href="/aussteller/baoding-shenchen-precision-pump/N1410043" image-large-bordered="" label-bookmark="Merken" label-bookmarked="Gemerkt" type="Aussteller 2019" url-bookmark="/api/remember/AU_10183334" v-theme="100">
# <template slot="headline">
# <h2 class="t set-300-bold as-headline search-snippet-name">Baoding Shenchen Precision Pump</h2>
# <h3 class="t set-040-wide as-copy search-snippet-attribute">Baoding - CN</h3>
# </template>
# <template slot="content">
# <div class="search-snippet-additional-detail">
# <div class="search-snippet-additional-detail-flex">
# <p class="t set-100-regular as-copy search-snippet-location"></p>
# </div>
# </div>
# </template>
# </o-search-snippet>
# </div>
# <div class="cell small-12">
# <o-search-snippet :divider="true" :image-src='["https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A921708/LOG_MO0_9fc32e9e-1b63-465b-93c6-d0ae8f28b72e_aeid_60__73_atomfeld_60_73-1314271556616661.jpg.png","https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A921708/LOG_TA0_9fc32e9e-1b63-465b-93c6-d0ae8f28b72e_aeid_60__73_atomfeld_60_73-1314271556616661.jpg.png","https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A921708/LOG_DE0_9fc32e9e-1b63-465b-93c6-d0ae8f28b72e_aeid_60__73_atomfeld_60_73-1314271556616661.jpg.png"]' href="/aussteller/beckman-coulter/C499226" image-large-bordered="" label-bookmark="Merken" label-bookmarked="Gemerkt" type="Aussteller 2019" url-bookmark="/api/remember/AU_10180289" v-theme="100">
# <template slot="headline">
# <h2 class="t set-300-bold as-headline search-snippet-name">Beckman Coulter</h2>
# <h3 class="t set-040-wide as-copy search-snippet-attribute">Krefeld - DE</h3>
# </template>
# <template slot="content">
# <p class="t set-200-regular as-copy search-snippet-description">Unternehmensbeschreibung:
# Beckman Coulter, als Teil der Danaher Corporation,  ist einer der weltweit führenden Hersteller von Messinstrumenten und ...</p>
# <div class="search-snippet-additional-detail">
# <div class="search-snippet-additional-detail-flex">
# <p class="t set-100-regular as-copy search-snippet-location"></p>
# </div>
# </div>
# </template>
# </o-search-snippet>
# </div>
# <div class="cell small-12">
# <o-search-snippet :divider="true" :image-src='["/files/files/assets/v3.34.3/assets/content/static/placeholder-exhibitor.png","/files/files/assets/v3.34.3/assets/content/static/placeholder-exhibitor.png","/files/files/assets/v3.34.3/assets/content/static/placeholder-exhibitor.png"]' href="/aussteller/beijing-solarbio-science-tech-/003658" image-large-bordered="" label-bookmark="Merken" label-bookmarked="Gemerkt" type="Aussteller 2019" url-bookmark="/api/remember/AU_10178775" v-theme="100">
# <template slot="headline">
# <h2 class="t set-300-bold as-headline search-snippet-name">Beijing Solarbio Science &amp; Tech.</h2>
# <h3 class="t set-040-wide as-copy search-snippet-attribute">Beijing - CN</h3>
# </template>
# <template slot="content">
# <div class="search-snippet-additional-detail">
# <div class="search-snippet-additional-detail-flex">
# <p class="t set-100-regular as-copy search-snippet-location"></p>
# </div>
# </div>
# </template>
# </o-search-snippet>
# </div>
# <div class="cell small-12">
# <o-search-snippet :divider="true" :image-src='["https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A921710/LOG_MO0_0ca801eb-ab71-4c30-9c67-d8f669d03eb3_aeid_60__73_atomfeld_60_73-1314291554274734.jpg.png","https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A921710/LOG_TA0_0ca801eb-ab71-4c30-9c67-d8f669d03eb3_aeid_60__73_atomfeld_60_73-1314291554274734.jpg.png","https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A921710/LOG_DE0_0ca801eb-ab71-4c30-9c67-d8f669d03eb3_aeid_60__73_atomfeld_60_73-1314291554274734.jpg.png"]' href="/aussteller/berthold-technologies/E336437" image-large-bordered="" label-bookmark="Merken" label-bookmarked="Gemerkt" type="Aussteller 2019" url-bookmark="/api/remember/AU_10180154" v-theme="100">
# <template slot="headline">
# <h2 class="t set-300-bold as-headline search-snippet-name">BERTHOLD TECHNOLOGIES</h2>
# <h3 class="t set-040-wide as-copy search-snippet-attribute">Bad Wildbad - DE</h3>
# </template>
# <template slot="content">
# <p class="t set-200-regular as-copy search-snippet-description">BERTHOLD TECHNOLOGIES - Bioanalytische Messgeräte made in Germany
#
# Berthold Technologies ist ein privat geführter Technologieführer im Bereich Life ...</p>
# <div class="search-snippet-additional-detail">
# <div class="search-snippet-additional-detail-flex">
# <p class="t set-100-regular as-copy search-snippet-location"></p>
# </div>
# </div>
# </template>
# </o-search-snippet>
# </div>
# <div class="cell small-12">
# <o-search-snippet :divider="true" :image-src='["https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A923653/LOG_MO0_21526_38566_155420294282158800_aeid_60__73_atomfeld_60_73-13142221554203546.jpg.png","https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A923653/LOG_TA0_21526_38566_155420294282158800_aeid_60__73_atomfeld_60_73-13142221554203546.jpg.png","https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A923653/LOG_DE0_21526_38566_155420294282158800_aeid_60__73_atomfeld_60_73-13142221554203546.jpg.png"]' href="/aussteller/biametrics/N1404849" image-large-bordered="" label-bookmark="Merken" label-bookmarked="Gemerkt" type="Aussteller 2019" url-bookmark="/api/remember/AU_20174780" v-theme="100">
# <template slot="headline">
# <h2 class="t set-300-bold as-headline search-snippet-name">Biametrics</h2>
# <h3 class="t set-040-wide as-copy search-snippet-attribute">Tübingen - DE</h3>
# </template>
# <template slot="content">
# <p class="t set-200-regular as-copy search-snippet-description">Biametrics bietet Lösungen für Next-generation Microarray Anwendungen. Unsere Technologie ermöglicht das markierungsfreie Screening und die kinetische ...</p>
# <div class="search-snippet-additional-detail">
# <div class="search-snippet-additional-detail-flex">
# <p class="t set-100-regular as-copy search-snippet-location"></p>
# </div>
# </div>
# </template>
# </o-search-snippet>
# </div>
# </template>
# <template slot="footer">
# <div class="cell small-12 search-snippet-list-divider">
# <o-divider v-theme="100">
# </o-divider>
# </div>
# <div class="cell small-12">
# <o-pagination-numeric class="as-center">
# <a class="o button circle as-bordered as-disabled" data-action="page" data-value="0" v-reactive-form.click="">
# <i class="o icon icon-bracket-left"></i>
# </a>
# <a class="o button circle as-active" data-action="page" data-value="1" v-reactive-form.click="">1</a>
# <a class="o button circle" data-action="page" data-value="2" v-reactive-form.click="">2</a>
# <a class="o button circle" data-action="page" data-value="3" v-reactive-form.click="">3</a>
# <span class="t copy as-inline gap">…</span>
# <a class="o button circle as-last" data-action="page" data-value="59" v-reactive-form.click="">59</a>
# <a class="o button circle as-bordered" data-action="page" data-value="2" v-reactive-form.click="">
# <i class="o icon icon-bracket-right"></i>
# </a>
# </o-pagination-numeric>
# </div>
# </template>
# </c-search-snippet-list>
# <input name="state" type="hidden" value="zTnx3oHs35Rd"/>
# <input name="category" type="hidden" value="ep"/>
# </c-search-results>
# <!--index_ignore_end-->
# <!--index_ignore_begin-->
# <!--index_ignore_end-->
# </div>
# <div class="flex-child-shrink">
# <!--index_ignore_begin-->
# <c-toolbar :module-theme="100" v-cloak="">
# <o-toolbar-bookmark-button :bookmarked="0" href="/de/applikation/dashboard/merkliste/#popover-login" tooltip-text="auf der Merkliste" unit-label="Eintrag" units-label="Einträge">
# </o-toolbar-bookmark-button>
# </c-toolbar>
# <c-footer href="https://www.messe.de/" logo-dark="/files/files/assets/v3.34.3/assets/content/static/logo-footer-75-years-de_ci.svg" logo-light="/files/files/assets/v3.34.3/assets/content/static/logo-footer-75-years-de_light.svg" target="_blank" v-cloak="" v-theme="100" v-tracking="{'navi': [['footer/dmag_logo']], 'type': 'event'}">
# <template slot="first-cell">
# <a class="item" href="/de/applikation/formulare/kontakt-allgemein/" v-tracking="{'navi': [['footer/kontakt']], 'type': 'event'}">Kontakt</a>
# <a class="item" href="/de/ueber-uns/presse/" v-tracking="{'navi': [['footer/presse']], 'type': 'event'}">Presse</a>
# <a class="item" href="/de/applikation/registrierung/newsletter/" v-tracking="{'navi': [['footer/newsletter']], 'type': 'event'}">Newsletter</a>
# <a class="item" href="/de/news/mediathek/index-2" v-tracking="{'navi': [['footer/mediathek']], 'type': 'event'}">Mediathek</a>
# </template>
# <template slot="second-cell">
# <a class="item" href="/de/ueber-uns/labvolution/" v-tracking="{'navi': [['footer/labvolution-2023']], 'type': 'event'}">LABVOLUTION 2023</a>
# </template>
# <template slot="third-cell">
# <a class="item" href="/de/deutsche-messe/" v-tracking="{'navi': [['footer/impressum']], 'type': 'event'}">Impressum</a>
# <a class="item" href="/de/deutsche-messe/datenschutz" v-tracking="{'navi': [['footer/datenschutz']], 'type': 'event'}">Datenschutz</a>
# <a class="item" href="/de/deutsche-messe/rechtliche-hinweise" v-tracking="{'navi': [['footer/rechtliche-hinweise']], 'type': 'event'}">Rechtliche Hinweise</a>
# <a class="item" href="/de/deutsche-messe/agb-ticketshop" v-tracking="{'navi': [['footer/agb-ticketshop']], 'type': 'event'}">AGB Ticketshop</a>
# </template>
# <template slot="fair-cell">
# </template>
# <template slot="share-icons">
# <o-share-icons>
# <a href="https://www.facebook.com/labvolution" rel="noopener noreferrer" target="_blank" v-tracking="{'navi': [['footer/social-icon-facebook']], 'type': 'event'}">
# <i class="icon icon-facebook-circle layout-link"></i>
# </a>
# <a href="https://www.linkedin.com/showcase/labvolution" rel="noopener noreferrer" target="_blank" v-tracking="{'navi': [['footer/social-icon-linkedin']], 'type': 'event'}">
# <i class="icon icon-linkedin-circle layout-link"></i>
# </a>
# </o-share-icons>
# </template>
# <template slot="language">
# </template>
# <template slot="hotline">Hotline:</template>
# <template href="tel:+49 (0)511 89-0" slot="hotline-number">+49 (0)511 89-0</template>
# <template slot="messe-name">Deutsche Messe AG</template>
# <template slot="cookie-consent">Cookie Einstellungen</template>
# </c-footer>
# <c-popover :no-use-navigation-bounding="true" class="as-dialog" data-type="c-popover" disable-closer="" id="popover-login" tracking="/tracking" v-cloak="">
# <c-form-login-form :has-login="true" action="/de/loginoverlay" email-label="E-Mail-Adresse" email-name="email" forget-link-href="/de/applikation/login/passwort-vergessen/" forget-link-label="Passwort vergessen?" headline="Login" password-label="Passwort" password-name="password" regist-header="Noch nicht angemeldet?" regist-link-href="/de/applikation/registrierung/account/" regist-link-label="Jetzt registrieren" submit-button-label="Einloggen" v-cloak="" v-theme="100">
# </c-form-login-form>
# </c-popover>
# <c-notifier fixed="bottom" v-cloak="">
# <o-notification button-class-name="notification-browser-button" button-href="https://browser-update.org/de/update.html?force_outdated=true" button-target="_blank" close-control-top-right="" error="" name="browser-notification" session-key="browser-notification" v-cloak="">
# <template slot="content">
# <h3 class="t set-100-bold as-headline">Browser Hinweis</h3>
# <p class="t set-040-wide as-copy">
# <span>Ihr Webbrowser ist veraltet. Aktualisieren Sie Ihren Browser für mehr Sicherheit, Geschwindigkeit und eine optimale Darstellung dieser Seite.</span>
# </p>
# </template>
# <template slot="button">
#                 Browser aktualisieren
#             </template>
# </o-notification>
# </c-notifier>
# <c-overlay :disable-closer="true" v-cloak=""></c-overlay>
# <!--index_ignore_end-->
# </div>
# </div>
# <portal-target name="dialog"></portal-target>
# </main>
# <script client-key="00002971-3e7fd93a-50e4-35ce-a4bf-d0cc619ddf84" container-id="1762" lang="de" src="https://d35ojb8dweouoy.cloudfront.net/loader/loader.js" type="text/javascript">
# </script>
# <script id="emos-settings" type="application/json">{"disabled":false,"pushDisabled":false,"disabledInitializationTracking":false,"disallowedCallers":[],"defaults":{"pageId":"web_1377653_1380069","cmsid":"web_1377653_1380069","siteid":"00079","langid":"de","intern":"web","content":"/de/suche/","search":null},"scriptUrl":"/files/files/assets/v3.34.3/assets/js/emos3.js","mediaScriptUrl":"/files/files/assets/v3.34.3/assets/js/econda-media-minimal.js"}</script>
# <script id="advertisment-settings" type="application/json">
# 		{
# 			"lang": "de",
# 			"default": {
# 				"siteId": "151937",
# 				"pageId": "1074940",
# 				"target": "keyword=null",
# 				"networkid": 1044,
# 				"async": true,
# 				"inSequence": true,
# 				"domain": "//www.smartadserver.com"
# 			},
# 			"scriptURL": "//ced.sascdn.com/tag/1044/smart.js",
# 			"stopAdvertisment": true
# 		}
# 	</script>
# <script defer="" src="/files/files/assets/v3.34.3/assets/js/vendor.js"></script>
# <script defer="" src="/files/files/assets/v3.34.3/assets/js/bootstrap.js"></script>
# <script async="">
# 		document.cookie = `utc_offset=${-new Date().getTimezoneOffset()}`
# 	</script>
# </body>
# </html>

# %%
print(soup2)
# # get the last page of of the url
# page_num_url = "https://swapi.dev/about"
# response = requests.get(page_num_url)
# page_num_soup = soup(response.text, "html.parser")
# page_num_div = page_num_soup.find('div' ,class_='col-sm-2 col-lg-2 col-md-2')
# page_num = page_num_div.find('p')
# page_num = page_num.text 
# # extract int(num) from the html tag
# for i in page_num.split():
#     if i.isdigit():
#        page_num = int(i)
# # extracted page number   
# page_num
# Out:
# <!DOCTYPE html>
#
# <html dir="ltr" lang="DE" prefix="og: http://ogp.me/ns#">
# <head>
# <meta charset="utf-8"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <title>Suche</title>
# <meta name="description"/>
# <meta content="DE" name="sprache"/>
# <meta name="keywords"/>
# <meta name="tags"/>
# <meta name="tag-synonyms"/>
# <meta content="Suche" name="headline"/>
# <meta name="primaryTagId"/>
# <meta name="primaryTagInterestId"/>
# <meta content="Artikel" name="meldungsart"/>
# <meta content="/files/files/079/media/bilder/applikation/teaser-application-pages/kundenbereich_3_2_tablet_706_470.jpg" name="teaserImage"/>
# <meta name="navParent"/>
# <meta content="width=device-width, initial-scale=1.0, minimum-scale=1.0, user-scalable=no" name="viewport"/>
# <meta name="media:xs"/>
# <meta name="media:sm"/>
# <meta name="media:md"/>
# <meta name="media:lg"/>
# <meta name="media:xl"/>
# <meta name="media:small"/>
# <meta name="media:medium"/>
# <meta name="media:large"/>
# <meta name="media:xlarge"/>
# <meta name="media:xxlarge"/>
# <meta content="labvolution" name="application-name">
# <meta content="#FFFFFF" name="msapplication-TileColor">
# <meta content="/files/files/assets/v3.34.3/assets/static/labvolution/meta/mstile-70x70-labvolution.png" name="msapplication-TileImage">
# <meta content="/files/files/assets/v3.34.3/assets/static/labvolution/meta/mstile-70x70-labvolution.png" name="msapplication-square70x70logo">
# <meta content="/files/files/assets/v3.34.3/assets/static/labvolution/meta/mstile-150x150-labvolution.png" name="msapplication-square150x150logo">
# <meta content="/files/files/assets/v3.34.3/assets/static/labvolution/meta/mstile-310x150-labvolution.png" name="msapplication-wide310x150logo"/>
# <meta content="/files/files/assets/v3.34.3/assets/static/labvolution/meta/mstile-310x310-labvolution.png" name="msapplication-square310x310logo"/>
# <meta content="yes" name="apple-mobile-web-app-capable"/>
# <meta content="black" name="apple-mobile-web-app-status-bar-style"/>
# <meta content="website" property="og:type"/>
# <meta content="https://www.labvolution.de" property="og:site_name"/>
# <meta content="https://www.labvolution.de/de/suche/" property="og:url"/>
# <meta property="og:title"/>
# <meta property="og:description"/>
# <meta content="/files/files/assets/v3.34.3/assets/static/labvolution/meta/og-labvolution.jpg" property="og:image"/>
# <meta content="1200" property="og:image:width"/>
# <meta content="630" property="og:image:height"/>
# <meta property="twitter:site"/>
# <meta content="summary_large_image" property="twitter:card"/>
# <link href="https://www.labvolution.de/de/suche/" rel="canonical"/>
# <link href="/files/files/assets/v3.34.3/assets/static/labvolution/meta/favicon-labvolution.ico" rel="icon" type="image/x-icon"/>
# <link href="/files/files/assets/v3.34.3/assets/static/labvolution/meta/apple-touch-icon-57x57-labvolution.png" rel="apple-touch-icon-precomposed" sizes="57x57"/>
# <link href="/files/files/assets/v3.34.3/assets/static/labvolution/meta/apple-touch-icon-60x60-labvolution.png" rel="apple-touch-icon-precomposed" sizes="60x60"/>
# <link href="/files/files/assets/v3.34.3/assets/static/labvolution/meta/apple-touch-icon-72x72-labvolution.png" rel="apple-touch-icon-precomposed" sizes="72x72"/>
# <link href="/files/files/assets/v3.34.3/assets/static/labvolution/meta/apple-touch-icon-76x76-labvolution.png" rel="apple-touch-icon-precomposed" sizes="76x76"/>
# <link href="/files/files/assets/v3.34.3/assets/static/labvolution/meta/apple-touch-icon-114x114-labvolution.png" rel="apple-touch-icon-precomposed" sizes="114x114"/>
# <link href="/files/files/assets/v3.34.3/assets/static/labvolution/meta/apple-touch-icon-120x120-labvolution.png" rel="apple-touch-icon-precomposed" sizes="120x120"/>
# <link href="/files/files/assets/v3.34.3/assets/static/labvolution/meta/apple-touch-icon-144x144-labvolution.png" rel="apple-touch-icon-precomposed" sizes="144x144"/>
# <link href="/files/files/assets/v3.34.3/assets/static/labvolution/meta/apple-touch-icon-152x152-labvolution.png" rel="apple-touch-icon-precomposed" sizes="152x152"/>
# <link href="/files/files/assets/v3.34.3/assets/static/labvolution/meta/favicon-16x16-labvolution.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="/files/files/assets/v3.34.3/assets/static/labvolution/meta/favicon-32x32-labvolution.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="/files/files/assets/v3.34.3/assets/static/labvolution/meta/favicon-96x96-labvolution.png" rel="icon" sizes="96x96" type="image/png"/>
# <link href="/files/files/assets/v3.34.3/assets/static/labvolution/meta/favicon-128x128-labvolution.png" rel="icon" sizes="128x128" type="image/png"/>
# <link href="/files/files/assets/v3.34.3/assets/static/labvolution/meta/favicon-196x196-labvolution.png" rel="icon" sizes="196x196" type="image/png"/>
# <link href="/files/files/assets/v3.34.3/assets/css/styles_app_light.css" rel="stylesheet"/>
# <link href="/files/files/assets/v3.34.3/assets/css/styles_labvolution.css" rel="stylesheet"/>
# <style type="text/css">
# 		.adesso-hide-first-divider > section.c.divider { display: none; }
# 		.adesso-hide-first-divider > section.c.divider ~ section.c.divider { display: block; }
# 	</style>
# </meta></meta></meta></meta></meta></head>
# <body class="application-page has-navigation is-labvolution messe-theme-light">
# <!-- Google Tag Manager -->
# <noscript><iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-PLPKMSX" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <script>//<![CDATA[
#
# 	dataLayer = [{
# 		"pageid": "GTM-PLPKMSX"
# 	}];
#
# 	(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({"gtm.start":
# 	new Date().getTime(),event:"gtm.js"});var f=d.getElementsByTagName(s)[0],
# 	j=d.createElement(s),dl=l!="dataLayer"?"&l="+l:"";j.async=true;j.src=
# 	"//www.googletagmanager.com/gtm.js?id="+i+dl;f.parentNode.insertBefore(j,f);
# 	})(window,document,"script","dataLayer","GTM-PLPKMSX");
#
# 	//]]></script>
# <!-- End Google Tag Manager -->
# <script id="application-settings" type="application/json">
# {
# 	"lang": "DE",
# 	"vstJahr": "2019",
# 	"ticketJahr": "2021",
# 	"vstNummer": "079",
# 	"csrf-token": "03f1435d-4e23-4619-a0db-810774db0cd4"
# }
# </script>
# <main id="app">
# <!--index_ignore_begin-->
# <c-navigation-main :visiting="-1" drawer-label="Menü" module-theme="100" superbanner-label="Anzeige" v-cloak="" v-theme="100">
# <template slot="meta-date">
# <a href="/de/ueber-uns/labvolution/">09. - 11. Mai 2023 |  LABVOLUTION</a>
# </template>
# <template slot="meta-date-small">
# <a href="/de/ueber-uns/labvolution/">09. - 11. Mai 2023 | </a>
# </template>
# <template slot="meta-dashboard">
# <a href="/de/applikation/dashboard/merkliste/#popover-login">Merkliste</a>
# </template>
# <template slot="meta-my-messe-not-loggedin">
# <a href="#popover-login" v-link="">Login</a>
# </template>
# <template slot="meta-my-messe">Mein Account</template>
# <template slot="meta-my-messe-dropdown">
# <div class="t set-040-wide as-cat-headline profile">Profil</div>
# <div>
# <a href="/de/applikation/dashboard/profil/">Nutzerkonto</a>
# </div>
# <div>
# <a href="/de/applikation/dashboard/news-service/">News-Service</a>
# </div>
# <c-form-frame action="/de/logout/" class="as-inline is-logout" method="POST" v-cloak="">
# <input name="_csrf" type="hidden" value="03f1435d-4e23-4619-a0db-810774db0cd4"/>
# <button class="item inline" type="submit">Abmelden</button>
# </c-form-frame>
# </template>
# <template slot="meta-logout-button-mobile">
# <c-form-frame action="/de/logout/" class="as-inline is-logout" method="POST" v-cloak="">
# <input name="_csrf" type="hidden" value="03f1435d-4e23-4619-a0db-810774db0cd4"/>
# <button class="hc sub-item" type="submit">
# <div class="sub-item-label t set-250-bold">Abmelden</div>
# </button>
# </c-form-frame>
# </template>
# <template slot="meta-login-mobile">
# <a class="menu-item mobile-menu-login t set-150-bold hide-for-large" href="#popover-login" v-link="">
# <span class="label">Login</span>
# </a>
# </template>
# <template slot="logo">
# <a href="/de/">
# <img src="/files/files/assets/v3.34.3/assets/static/labvolution/logo/logo-light-labvolution.svg"/>
# </a>
# </template>
# <template slot="logo-small">
# <a href="/de/">
# <img src="/files/files/assets/v3.34.3/assets/static/labvolution/logo/logo-light-mobile-labvolution.svg"/>
# </a>
# </template>
# <template slot="search-input">
# <input placeholder="Suchbegriff eingeben...">
# </input></template>
# <template slot="menu">
# <o-navigation-item>
# <a class="visiting" href="/de/ueber-uns/" slot="menu-item">Über LABVOLUTION 2023</a>
# <template slot="submenu-items">
# <a href="/de/ueber-uns/labvolution/">LABVOLUTION 2023</a><a href="/de/ueber-uns/labvolution-award/">LABVOLUTION AWARD</a><a href="/de/ueber-uns/aussteller-produktsuche/">Rückblick Aussteller &amp; Produkte 2019</a><a href="/de/ueber-uns/presse/">Presse</a><a href="/de/ueber-uns/mediathek/index-2">Mediathek</a><a href="/de/ueber-uns/ueber-smartlab-connects/">Über smartLAB connects 2021</a>
# </template>
# </o-navigation-item>
# </template>
# <template slot="other-actions">
# <i class="icon icon-search"></i>
# </template>
# </c-navigation-main>
# <c-navigation-search no-ads="true" superbanner-label="Anzeige" v-cloak="" v-theme="300">
# <div class="grid-x grid-padding-x">
# <div class="cell small-12 medium-10 medium-offset-1 large-6 large-offset-3">
# <c-search-bar action="/de/suche/" auto-suggest="/autocomplete?locale=D&amp;search={s}" autocomplete="off" dimmer="" fixed="" form="" method="POST" module-theme="300" placeholder="Suchbegriff eingeben..." v-cloak="">
# <div class="grid-container">
# <div class="grid-x align-center">
# </div>
# </div>
# </c-search-bar>
# </div>
# </div>
# </c-navigation-search>
# <!--index_ignore_end-->
# <div class="flex-container flex-dir-column fullheight">
# <div class="flex-child-grow">
# <!--index_ignore_begin-->
# <c-search-results action="/de/suche/" button-label="Suche eingrenzen" has-filter-boxes="true" method="POST" v-cloak="" v-theme="100">
# <template slot="header">
# <c-search-header v-cloak="" v-theme="300">
# <template slot="search">
# <c-search-bar auto-suggest="/autocomplete?locale=D&amp;search={s}&amp;rt=EXHIBITOR,PRODUCT" autocomplete="off" mobile-placeholder="Aussteller &amp; Produkte suchen" module-theme="300" placeholder="Neue Suche nach Ausstellern &amp; Produkten" v-cloak="">
# </c-search-bar>
# </template>
# </c-search-header>
# <div class="grid-container">
# <div class="search-results-content-links responsive-margin">
# <a class="t set-040-caps set-caption as-caption icon icon-hamburger" href="/de/ausstellung/ausstellerliste/">
# <span>Zur Ausstellerliste</span>
# </a>
# <a class="t set-040-caps set-caption as-caption icon icon-search" href="/de/ausstellung/produktgruppen/index-2">
# <span>Zum Produktgruppenverzeichnis</span>
# </a>
# </div>
# </div>
# </template>
# <template slot="filter">
# <c-search-filter-singlechoice v-cloak="" v-theme="100">
# <template slot="header">
# <a class="t set-080-regular back-button" data-action="resultCategoryReset" v-reactive-form.click="">
# <i class="icon as-icon-size-small icon-bracket-left"></i>
#                             Alle Kategorien
#                         </a>
# <h3 class="t set-400-bold">Aussteller &amp; Produkte</h3>
# <div class="search-filter-singlechoice-divider">
# <o-divider v-theme="100">
# </o-divider>
# </div>
# </template>
# <template slot="content">
# <c-full-search-filter-box :init-items="3" :items-length="3" headline="Treffertyp" less="Weniger anzeigen" more="Alle anzeigen">
# <template slot="reset">
# </template>
# <template>
# <div>
# <o-form-checkbox data-action="filter" data-class="ht" data-value="Aussteller" v-reactive-form.change="">
# <template slot="label">
# <span class="t set-080-regular">Aussteller</span>
# <span class="filter-results">(290)</span>
# </template>
# </o-form-checkbox>
# </div>
# <div>
# <o-form-checkbox data-action="filter" data-class="ht" data-value="Produkt" v-reactive-form.change="">
# <template slot="label">
# <span class="t set-080-regular">Produkte</span>
# <span class="filter-results">(881)</span>
# </template>
# </o-form-checkbox>
# </div>
# <div>
# <o-form-checkbox data-action="filter" data-class="ht" data-value="Sonderpräsentation" v-reactive-form.change="">
# <template slot="label">
# <span class="t set-080-regular">Sonderpräsentationen</span>
# <span class="filter-results">(1)</span>
# </template>
# </o-form-checkbox>
# </div>
# </template>
# </c-full-search-filter-box><c-full-search-filter-box :init-items="3" :items-length="2" headline="Neuheiten" less="Weniger anzeigen" more="Alle anzeigen">
# <template slot="reset">
# </template>
# <template>
# <div>
# <o-form-checkbox data-action="filter" data-class="pt" data-value="FE-Projekt" v-reactive-form.change="">
# <template slot="label">
# <span class="t set-080-regular">F&amp;E-Projekte</span>
# <span class="filter-results">(13)</span>
# </template>
# </o-form-checkbox>
# </div>
# <div>
# <o-form-checkbox data-action="filter" data-class="pt" data-value="Messepremiere" v-reactive-form.change="">
# <template slot="label">
# <span class="t set-080-regular">Messepremieren</span>
# <span class="filter-results">(131)</span>
# </template>
# </o-form-checkbox>
# </div>
# </template>
# </c-full-search-filter-box><c-full-search-filter-box :init-items="3" :items-length="9" headline="Produktgruppen" less="Weniger anzeigen" more="Alle anzeigen">
# <template slot="reset">
# </template>
# <template>
# <div>
# <a class="t set-100-regular filter-item" data-action="filter" data-class="pg" data-value="531781" v-reactive-form.click="">
#
# 						Analytik
# 						<span class="filter-results">(323)</span>
# </a>
# </div>
# <div>
# <a class="t set-100-regular filter-item" data-action="filter" data-class="pg" data-value="531835" v-reactive-form.click="">
#
# 						Anwendungen in der Biotechnologie
# 						<span class="filter-results">(379)</span>
# </a>
# </div>
# <div>
# <a class="t set-100-regular filter-item" data-action="filter" data-class="pg" data-value="531823" v-reactive-form.click="">
#
# 						Anwendungen und Verfahren
# 						<span class="filter-results">(111)</span>
# </a>
# </div>
# <div class="hidden">
# <a class="t set-100-regular filter-item" data-action="filter" data-class="pg" data-value="531818" v-reactive-form.click="">
#
# 						Chemikalien, Reagenzien, Bedarfs- und Verbrauchsartikel
# 						<span class="filter-results">(156)</span>
# </a>
# </div>
# <div class="hidden">
# <a class="t set-100-regular filter-item" data-action="filter" data-class="pg" data-value="531897" v-reactive-form.click="">
#
# 						Fachbezogene Dienstleistungen
# 						<span class="filter-results">(22)</span>
# </a>
# </div>
# <div class="hidden">
# <a class="t set-100-regular filter-item" data-action="filter" data-class="pg" data-value="531883" v-reactive-form.click="">
#
# 						Forschungsinstitute, Universitäten, Hochschulen und Karriere
# 						<span class="filter-results">(52)</span>
# </a>
# </div>
# <div class="hidden">
# <a class="t set-100-regular filter-item" data-action="filter" data-class="pg" data-value="531801" v-reactive-form.click="">
#
# 						Informatik, Digitalisierung, Big Data
# 						<span class="filter-results">(93)</span>
# </a>
# </div>
# <div class="hidden">
# <a class="t set-100-regular filter-item" data-action="filter" data-class="pg" data-value="531755" v-reactive-form.click="">
#
# 						Labortechnik und -infrastruktur, Laborautomation
# 						<span class="filter-results">(628)</span>
# </a>
# </div>
# <div class="hidden">
# <a class="t set-100-regular filter-item" data-action="filter" data-class="pg" data-value="531891" v-reactive-form.click="">
#
# 						Verbände und Institutionen
# 						<span class="filter-results">(10)</span>
# </a>
# </div>
# </template>
# </c-full-search-filter-box><c-full-search-filter-box :init-items="3" :items-length="17" headline="Anwendungsbereiche" less="Weniger anzeigen" more="Alle anzeigen">
# <template slot="reset">
# </template>
# <template>
# <div>
# <a class="t set-100-regular filter-item" data-action="filter" data-class="zb" data-value="1501" v-reactive-form.click="">
#
# 						Alle Branchen, branchenunabhängig
# 						<span class="filter-results">(14)</span>
# </a>
# </div>
# <div>
# <a class="t set-100-regular filter-item" data-action="filter" data-class="zb" data-value="1298" v-reactive-form.click="">
#
# 						Behörden &amp; Öffentliche Dienste
# 						<span class="filter-results">(2)</span>
# </a>
# </div>
# <div>
# <a class="t set-100-regular filter-item" data-action="filter" data-class="zb" data-value="1220" v-reactive-form.click="">
#
# 						Bergbau und Gewinnung von Steinen und Erden
# 						<span class="filter-results">(5)</span>
# </a>
# </div>
# <div class="hidden">
# <a class="t set-100-regular filter-item" data-action="filter" data-class="zb" data-value="1104" v-reactive-form.click="">
#
# 						Energieversorgung
# 						<span class="filter-results">(10)</span>
# </a>
# </div>
# <div class="hidden">
# <a class="t set-100-regular filter-item" data-action="filter" data-class="zb" data-value="1108" v-reactive-form.click="">
#
# 						Entsorgung &amp; Recycling
# 						<span class="filter-results">(7)</span>
# </a>
# </div>
# <div class="hidden">
# <a class="t set-100-regular filter-item" data-action="filter" data-class="zb" data-value="1411" v-reactive-form.click="">
#
# 						Erbringung von freiberuflichen, wissenschaftlichen und technischen Dienstleistungen
# 						<span class="filter-results">(16)</span>
# </a>
# </div>
# <div class="hidden">
# <a class="t set-100-regular filter-item" data-action="filter" data-class="zb" data-value="1275" v-reactive-form.click="">
#
# 						Erbringung von sonstigen wirtschaftlichen Dienstleistungen
# 						<span class="filter-results">(10)</span>
# </a>
# </div>
# <div class="hidden">
# <a class="t set-100-regular filter-item" data-action="filter" data-class="zb" data-value="1307" v-reactive-form.click="">
#
# 						Erziehung und Unterricht
# 						<span class="filter-results">(5)</span>
# </a>
# </div>
# <div class="hidden">
# <a class="t set-100-regular filter-item" data-action="filter" data-class="zb" data-value="1423" v-reactive-form.click="">
#
# 						Forschung und Entwicklung
# 						<span class="filter-results">(62)</span>
# </a>
# </div>
# <div class="hidden">
# <a class="t set-100-regular filter-item" data-action="filter" data-class="zb" data-value="1371" v-reactive-form.click="">
#
# 						Gastgewerbe/Beherbergung und Gastronomie
# 						<span class="filter-results">(2)</span>
# </a>
# </div>
# <div class="hidden">
# <a class="t set-100-regular filter-item" data-action="filter" data-class="zb" data-value="1314" v-reactive-form.click="">
#
# 						Gesundheits- und Sozialwesen
# 						<span class="filter-results">(38)</span>
# </a>
# </div>
# <div class="hidden">
# <a class="t set-100-regular filter-item" data-action="filter" data-class="zb" data-value="1126" v-reactive-form.click="">
#
# 						Handel; Instandhaltung und Reparatur von Kraftfahrzeugen
# 						<span class="filter-results">(9)</span>
# </a>
# </div>
# <div class="hidden">
# <a class="t set-100-regular filter-item" data-action="filter" data-class="zb" data-value="1381" v-reactive-form.click="">
#
# 						Information und Kommunikation
# 						<span class="filter-results">(3)</span>
# </a>
# </div>
# <div class="hidden">
# <a class="t set-100-regular filter-item" data-action="filter" data-class="zb" data-value="1327" v-reactive-form.click="">
#
# 						Kunst, Unterhaltung und Erholung
# 						<span class="filter-results">(2)</span>
# </a>
# </div>
# <div class="hidden">
# <a class="t set-100-regular filter-item" data-action="filter" data-class="zb" data-value="1203" v-reactive-form.click="">
#
# 						Land- und Forstwirtschaft, Fischerei
# 						<span class="filter-results">(4)</span>
# </a>
# </div>
# <div class="hidden">
# <a class="t set-100-regular filter-item" data-action="filter" data-class="zb" data-value="1781" v-reactive-form.click="">
#
# 						Schüler, Studenten
# 						<span class="filter-results">(6)</span>
# </a>
# </div>
# <div class="hidden">
# <a class="t set-100-regular filter-item" data-action="filter" data-class="zb" data-value="1237" v-reactive-form.click="">
#
# 						Verarbeitendes Gewerbe/Produktion
# 						<span class="filter-results">(78)</span>
# </a>
# </div>
# </template>
# </c-full-search-filter-box><c-full-search-filter-box :init-items="3" :items-length="8" headline="Herkunft" less="Weniger anzeigen" more="Alle anzeigen">
# <template slot="reset">
# </template>
# <template>
# <div>
# <a class="t set-100-regular filter-item" data-action="filter" data-class="or" data-value="101" v-reactive-form.click="">
#
# 						EU - Länder
# 						<span class="filter-results">(962)</span>
# </a>
# </div>
# <div>
# <a class="t set-100-regular filter-item" data-action="filter" data-class="or" data-value="301" v-reactive-form.click="">
#
# 						Nordamerika
# 						<span class="filter-results">(23)</span>
# </a>
# </div>
# <div>
# <a class="t set-100-regular filter-item" data-action="filter" data-class="or" data-value="402" v-reactive-form.click="">
#
# 						Ostasien
# 						<span class="filter-results">(135)</span>
# </a>
# </div>
# <div class="hidden">
# <a class="t set-100-regular filter-item" data-action="filter" data-class="or" data-value="111" v-reactive-form.click="">
#
# 						Sonst.europ. Länder (ohne EU)
# 						<span class="filter-results">(52)</span>
# </a>
# </div>
# </template>
# </c-full-search-filter-box>
# </template>
# </c-search-filter-singlechoice>
# </template>
# <div class="grid-x search-results-select">
# <div class="cell medium-9 number-of-results">
# <h3 class="t set-400-bold as-headline">
# <span>1.172</span>
# <span>Treffer</span>
# </h3>
# </div>
# <div class="cell medium-3">
# <o-form-select :is-floating-label="false" :items='[{"value":"bAZ","label":"A-Z"},{"value":"RANKING","label":"Relevanz"}]' class="not-boxed" data-action="sort" fullwidth="" label="Sortieren nach" v-reactive-form.change="" value="bAZ">
# </o-form-select>
# </div>
# </div>
# <c-search-snippet-list v-cloak="" v-theme="100">
# <template slot="content">
# <div class="cell small-12">
# <o-search-snippet :divider="true" :image-src='["https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A921694/LOG_MO0_21526_38566_155386041881616600_aeid_60__73_atomfeld_60_73-1314141553860464.jpg.png","https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A921694/LOG_TA0_21526_38566_155386041881616600_aeid_60__73_atomfeld_60_73-1314141553860464.jpg.png","https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A921694/LOG_DE0_21526_38566_155386041881616600_aeid_60__73_atomfeld_60_73-1314141553860464.jpg.png"]' href="/aussteller/abbott-informatics-germany/N1404331" image-large-bordered="" label-bookmark="Merken" label-bookmarked="Gemerkt" type="Aussteller 2019" url-bookmark="/api/remember/AU_20174677" v-theme="100">
# <template slot="headline">
# <h2 class="t set-300-bold as-headline search-snippet-name">Abbott Informatics Germany</h2>
# <h3 class="t set-040-wide as-copy search-snippet-attribute">Witten - DE</h3>
# </template>
# <template slot="content">
# <p class="t set-200-regular as-copy search-snippet-description">Mit der Erfahrung von mehr als 30 Jahren in der Laborinformatikbranche unterstützt Abbott Informatics mit seiner STARLIMS Lösung Unternehmen bei der ...</p>
# <div class="search-snippet-additional-detail">
# <div class="search-snippet-additional-detail-flex">
# <p class="t set-100-regular as-copy search-snippet-location"></p>
# </div>
# </div>
# </template>
# </o-search-snippet>
# </div>
# <div class="cell small-12">
# <o-search-snippet :divider="true" :image-src='["https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A921695/LOG_MO0_921695_01813358.jpg.png","https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A921695/LOG_TA0_921695_01813358.jpg.png","https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A921695/LOG_DE0_921695_01813358.jpg.png"]' href="/aussteller/abdos-labtech/E765861" image-large-bordered="" label-bookmark="Merken" label-bookmarked="Gemerkt" type="Aussteller 2019" url-bookmark="/api/remember/AU_10179634" v-theme="100">
# <template slot="headline">
# <h2 class="t set-300-bold as-headline search-snippet-name">Abdos Labtech</h2>
# <h3 class="t set-040-wide as-copy search-snippet-attribute">New Delhi 110025 - IN</h3>
# </template>
# <template slot="content">
# <div class="search-snippet-additional-detail">
# <div class="search-snippet-additional-detail-flex">
# <p class="t set-100-regular as-copy search-snippet-location"></p>
# </div>
# </div>
# </template>
# </o-search-snippet>
# </div>
# <div class="cell small-12">
# <o-search-snippet :divider="true" :image-src='["https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A921696/LOG_MO0_21526_38566_155662867981783800_aeid_60__73_atomfeld_60_73-1314161556628780.png.png","https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A921696/LOG_TA0_21526_38566_155662867981783800_aeid_60__73_atomfeld_60_73-1314161556628780.png.png","https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A921696/LOG_DE0_21526_38566_155662867981783800_aeid_60__73_atomfeld_60_73-1314161556628780.png.png"]' href="/aussteller/absource-diagnostics/N1404332" image-large-bordered="" label-bookmark="Merken" label-bookmarked="Gemerkt" type="Aussteller 2019" url-bookmark="/api/remember/AU_10182540" v-theme="100">
# <template slot="headline">
# <h2 class="t set-300-bold as-headline search-snippet-name">ABSOURCE Diagnostics</h2>
# <h3 class="t set-040-wide as-copy search-snippet-attribute">München - DE</h3>
# </template>
# <template slot="content">
# <p class="t set-200-regular as-copy search-snippet-description">Absource Diagnostics ist der Ansprechpartner Ihrer Wahl, wenn Sie effiziente hochqualitative Laborreagenzien zu fairen Preisen suchen.</p>
# <div class="search-snippet-additional-detail">
# <div class="search-snippet-additional-detail-flex">
# <p class="t set-100-regular as-copy search-snippet-location"></p>
# </div>
# </div>
# </template>
# </o-search-snippet>
# </div>
# <div class="cell small-12">
# <o-search-snippet :divider="true" :image-src='["https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A921697/LOG_MO0_f37dd3cd-2bb3-499f-86bc-0b18e4d913f0_aeid_60__73_atomfeld_60_73-1314171554280181.jpg.png","https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A921697/LOG_TA0_f37dd3cd-2bb3-499f-86bc-0b18e4d913f0_aeid_60__73_atomfeld_60_73-1314171554280181.jpg.png","https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A921697/LOG_DE0_f37dd3cd-2bb3-499f-86bc-0b18e4d913f0_aeid_60__73_atomfeld_60_73-1314171554280181.jpg.png"]' href="/aussteller/academics/V830521" image-large-bordered="" label-bookmark="Merken" label-bookmarked="Gemerkt" type="Aussteller 2019" url-bookmark="/api/remember/AU_10178212" v-theme="100">
# <template slot="headline">
# <h2 class="t set-300-bold as-headline search-snippet-name">academics</h2>
# <h3 class="t set-040-wide as-copy search-snippet-attribute">Hamburg - DE</h3>
# </template>
# <template slot="content">
# <p class="t set-200-regular as-copy search-snippet-description">academics ist der führende Stellenmarkt und Karrierebegleiter aus der ZEIT-Verlagsgruppe. Der Stellenmarkt bietet für alle, die Lust auf Wissenschaft und ...</p>
# <div class="search-snippet-additional-detail">
# <div class="search-snippet-additional-detail-flex">
# <p class="t set-100-regular as-copy search-snippet-location"></p>
# </div>
# </div>
# </template>
# </o-search-snippet>
# </div>
# <div class="cell small-12">
# <o-search-snippet :divider="true" :image-src='["https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A921698/LOG_MO0_21526_38566_155175837173356000_aeid_60__73_atomfeld_60_73-1314181551758420.png.png","https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A921698/LOG_TA0_21526_38566_155175837173356000_aeid_60__73_atomfeld_60_73-1314181551758420.png.png","https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A921698/LOG_DE0_21526_38566_155175837173356000_aeid_60__73_atomfeld_60_73-1314181551758420.png.png"]' href="/aussteller/accubiomed/003594" image-large-bordered="" label-bookmark="Merken" label-bookmarked="Gemerkt" type="Aussteller 2019" url-bookmark="/api/remember/AU_10180296" v-theme="100">
# <template slot="headline">
# <h2 class="t set-300-bold as-headline search-snippet-name">AccuBioMed</h2>
# <h3 class="t set-040-wide as-copy search-snippet-attribute">New Taipei City - TW</h3>
# </template>
# <template slot="content">
# <div class="search-snippet-additional-detail">
# <div class="search-snippet-additional-detail-flex">
# <p class="t set-100-regular as-copy search-snippet-location"></p>
# </div>
# </div>
# </template>
# </o-search-snippet>
# </div>
# <div class="cell small-12">
# <o-search-snippet :divider="true" :image-src='["https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A921699/LOG_MO0_921699_01813376.jpg.png","https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A921699/LOG_TA0_921699_01813376.jpg.png","https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A921699/LOG_DE0_921699_01813376.jpg.png"]' href="/aussteller/advanced-microfluidics/G181010" image-large-bordered="" label-bookmark="Merken" label-bookmarked="Gemerkt" type="Aussteller 2019" url-bookmark="/api/remember/AU_10182501" v-theme="100">
# <template slot="headline">
# <h2 class="t set-300-bold as-headline search-snippet-name">Advanced Microfluidics</h2>
# <h3 class="t set-040-wide as-copy search-snippet-attribute">Ecublens - CH</h3>
# </template>
# <template slot="content">
# <div class="search-snippet-additional-detail">
# <div class="search-snippet-additional-detail-flex">
# <p class="t set-100-regular as-copy search-snippet-location"></p>
# </div>
# </div>
# </template>
# </o-search-snippet>
# </div>
# <div class="cell small-12">
# <o-search-snippet :divider="true" :image-src='["https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A926234/LOG_MO0_926234_01838235.jpg.png","https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A926234/LOG_TA0_926234_01838235.jpg.png","https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A926234/LOG_DE0_926234_01838235.jpg.png"]' href="/aussteller/aicos-technologies/P636533" image-large-bordered="" label-bookmark="Merken" label-bookmarked="Gemerkt" type="Aussteller 2019" url-bookmark="/api/remember/AU_10182927" v-theme="100">
# <template slot="headline">
# <h2 class="t set-300-bold as-headline search-snippet-name">AICOS Technologies</h2>
# <h3 class="t set-040-wide as-copy search-snippet-attribute">Allschwil - CH</h3>
# </template>
# <template slot="content">
# <p class="t set-200-regular as-copy search-snippet-description">AICOS Technologies bietet Beratungsdienstleistungen und spezialisierte Software, die auf die Bedürfnisse der Prozessindustrie zugeschnitten sind, in ...</p>
# <div class="search-snippet-additional-detail">
# <div class="search-snippet-additional-detail-flex">
# <p class="t set-100-regular as-copy search-snippet-location"></p>
# </div>
# </div>
# </template>
# </o-search-snippet>
# </div>
# <div class="cell small-12">
# <o-search-snippet :divider="true" :image-src='["https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A921700/LOG_MO0_921700_01813391.jpg.png","https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A921700/LOG_TA0_921700_01813391.jpg.png","https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A921700/LOG_DE0_921700_01813391.jpg.png"]' href="/aussteller/analytik-jena/K637471" image-large-bordered="" label-bookmark="Merken" label-bookmarked="Gemerkt" type="Aussteller 2019" url-bookmark="/api/remember/AU_10177830" v-theme="100">
# <template slot="headline">
# <h2 class="t set-300-bold as-headline search-snippet-name">Analytik Jena</h2>
# <h3 class="t set-040-wide as-copy search-snippet-attribute">Jena - DE</h3>
# </template>
# <template slot="content">
# <p class="t set-200-regular as-copy search-snippet-description">Die Analytik Jena ist ein führender Anbieter von High-End-Analysemesstechnik, Instrumenten und Produkten im Bereich der Biotechnologie und der molekularen ...</p>
# <div class="search-snippet-additional-detail">
# <div class="search-snippet-additional-detail-flex">
# <p class="t set-100-regular as-copy search-snippet-location"></p>
# </div>
# </div>
# </template>
# </o-search-snippet>
# </div>
# <div class="cell small-12">
# <o-search-snippet :divider="true" :image-src='["https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A921757/LOG_MO0_21526_38566_155067699819858500_aeid_60__73_atomfeld_60_73-1314761550677424.jpg.png","https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A921757/LOG_TA0_21526_38566_155067699819858500_aeid_60__73_atomfeld_60_73-1314761550677424.jpg.png","https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A921757/LOG_DE0_21526_38566_155067699819858500_aeid_60__73_atomfeld_60_73-1314761550677424.jpg.png"]' href="/aussteller/analytik-news/N1404362" image-large-bordered="" label-bookmark="Merken" label-bookmarked="Gemerkt" type="Aussteller 2019" url-bookmark="/api/remember/AU_10182401" v-theme="100">
# <template slot="headline">
# <h2 class="t set-300-bold as-headline search-snippet-name">Analytik NEWS</h2>
# <h3 class="t set-040-wide as-copy search-snippet-attribute">Ober-Ramstadt - DE</h3>
# </template>
# <template slot="content">
# <p class="t set-200-regular as-copy search-snippet-description">Analytik NEWS ist ein unabhängiges Online-Labormagazin, das bereits seit 1998 tagesaktuelle, redaktionell geprüfte Informationen für Labor, Analytik, ...</p>
# <div class="search-snippet-additional-detail">
# <div class="search-snippet-additional-detail-flex">
# <p class="t set-100-regular as-copy search-snippet-location"></p>
# </div>
# </div>
# </template>
# </o-search-snippet>
# </div>
# <div class="cell small-12">
# <o-search-snippet :divider="true" :image-src='["https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A921702/LOG_MO0_a66d7d0e-1002-4ab2-a0d4-74ced1ca0b97_aeid_60__73_atomfeld_60_73-1314221554559722.jpg.png","https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A921702/LOG_TA0_a66d7d0e-1002-4ab2-a0d4-74ced1ca0b97_aeid_60__73_atomfeld_60_73-1314221554559722.jpg.png","https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A921702/LOG_DE0_a66d7d0e-1002-4ab2-a0d4-74ced1ca0b97_aeid_60__73_atomfeld_60_73-1314221554559722.jpg.png"]' href="/aussteller/andrew-alliance/V885357" image-large-bordered="" label-bookmark="Merken" label-bookmarked="Gemerkt" type="Aussteller 2019" url-bookmark="/api/remember/AU_10176938" v-theme="100">
# <template slot="headline">
# <h2 class="t set-300-bold as-headline search-snippet-name">Andrew Alliance</h2>
# <h3 class="t set-040-wide as-copy search-snippet-attribute">Vernier - CH</h3>
# </template>
# <template slot="content">
# <div class="search-snippet-additional-detail">
# <div class="search-snippet-additional-detail-flex">
# <p class="t set-100-regular as-copy search-snippet-location"></p>
# </div>
# </div>
# </template>
# </o-search-snippet>
# </div>
# <div class="cell small-12">
# <o-search-snippet :divider="true" :image-src='["https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A934561/LOG_MO0_21526_38566_155446869265655800_aeid_60__73_atomfeld_60_73-13142531554468719.png.png","https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A934561/LOG_TA0_21526_38566_155446869265655800_aeid_60__73_atomfeld_60_73-13142531554468719.png.png","https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A934561/LOG_DE0_21526_38566_155446869265655800_aeid_60__73_atomfeld_60_73-13142531554468719.png.png"]' href="/aussteller/anvajo/N1411582" image-large-bordered="" label-bookmark="Merken" label-bookmarked="Gemerkt" type="Aussteller 2019" url-bookmark="/api/remember/AU_19048155" v-theme="100">
# <template slot="headline">
# <h2 class="t set-300-bold as-headline search-snippet-name">anvajo</h2>
# <h3 class="t set-040-wide as-copy search-snippet-attribute">Dresden - DE</h3>
# </template>
# <template slot="content">
# <p class="t set-200-regular as-copy search-snippet-description">Die anvajo GmbH, ein Spin-off-Unternehmen der Technischen Universität Dresden, ist Entwickler und Hersteller von Point-of-Care-Lösungen für die ...</p>
# <div class="search-snippet-additional-detail">
# <div class="search-snippet-additional-detail-flex">
# <p class="t set-100-regular as-copy search-snippet-location"></p>
# </div>
# </div>
# </template>
# </o-search-snippet>
# </div>
# <div class="cell small-12">
# <o-search-snippet :divider="true" :image-src='["https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A921703/LOG_MO0_2b4f6be8-1915-464c-adfd-08f009916097_aeid_60__73_atomfeld_60_73-1314231554719642.png.png","https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A921703/LOG_TA0_2b4f6be8-1915-464c-adfd-08f009916097_aeid_60__73_atomfeld_60_73-1314231554719642.png.png","https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A921703/LOG_DE0_2b4f6be8-1915-464c-adfd-08f009916097_aeid_60__73_atomfeld_60_73-1314231554719642.png.png"]' href="/aussteller/apollo-scientific/L162000" image-large-bordered="" label-bookmark="Merken" label-bookmarked="Gemerkt" type="Aussteller 2019" url-bookmark="/api/remember/AU_10177903" v-theme="100">
# <template slot="headline">
# <h2 class="t set-300-bold as-headline search-snippet-name">Apollo Scientific</h2>
# <h3 class="t set-040-wide as-copy search-snippet-attribute">Stockport SK6 2QR - GB</h3>
# </template>
# <template slot="content">
# <div class="search-snippet-additional-detail">
# <div class="search-snippet-additional-detail-flex">
# <p class="t set-100-regular as-copy search-snippet-location"></p>
# </div>
# </div>
# </template>
# </o-search-snippet>
# </div>
# <div class="cell small-12">
# <o-search-snippet :divider="true" :image-src='["https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A934562/LOG_MO0_21526_38566_155436350964074600_aeid_60__73_atomfeld_60_73-13142541554363561.png.png","https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A934562/LOG_TA0_21526_38566_155436350964074600_aeid_60__73_atomfeld_60_73-13142541554363561.png.png","https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A934562/LOG_DE0_21526_38566_155436350964074600_aeid_60__73_atomfeld_60_73-13142541554363561.png.png"]' href="/aussteller/aquila-biolabs/N1411583" image-large-bordered="" label-bookmark="Merken" label-bookmarked="Gemerkt" type="Aussteller 2019" url-bookmark="/api/remember/AU_19048157" v-theme="100">
# <template slot="headline">
# <h2 class="t set-300-bold as-headline search-snippet-name">aquila biolabs</h2>
# <h3 class="t set-040-wide as-copy search-snippet-attribute">Baesweiler - DE</h3>
# </template>
# <template slot="content">
# <div class="search-snippet-additional-detail">
# <div class="search-snippet-additional-detail-flex">
# <p class="t set-100-regular as-copy search-snippet-location"></p>
# </div>
# </div>
# </template>
# </o-search-snippet>
# </div>
# <div class="cell small-12">
# <o-search-snippet :divider="true" :image-src='["https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A921704/LOG_MO0_21526_38566_155076713339991000_aeid_60__73_atomfeld_60_73-1314241550767901.jpg.png","https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A921704/LOG_TA0_21526_38566_155076713339991000_aeid_60__73_atomfeld_60_73-1314241550767901.jpg.png","https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A921704/LOG_DE0_21526_38566_155076713339991000_aeid_60__73_atomfeld_60_73-1314241550767901.jpg.png"]' href="/aussteller/autoscribe-informatics/003587" image-large-bordered="" label-bookmark="Merken" label-bookmarked="Gemerkt" type="Aussteller 2019" url-bookmark="/api/remember/AU_10179444" v-theme="100">
# <template slot="headline">
# <h2 class="t set-300-bold as-headline search-snippet-name">Autoscribe Informatics</h2>
# <h3 class="t set-040-wide as-copy search-snippet-attribute">Reading RG7 8DA - GB</h3>
# </template>
# <template slot="content">
# <p class="t set-200-regular as-copy search-snippet-description">Unsere branchenführenden Laborinformations-Managementsysteme (LIMS) und Qualitätsmanagementsysteme werden weltweit von Laboren eingesetzt. Dank unserer ...</p>
# <div class="search-snippet-additional-detail">
# <div class="search-snippet-additional-detail-flex">
# <p class="t set-100-regular as-copy search-snippet-location"></p>
# </div>
# </div>
# </template>
# </o-search-snippet>
# </div>
# <div class="cell small-12">
# <o-search-snippet :divider="true" :image-src='["https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A921706/LOG_MO0_921706_01813415.jpg.png","https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A921706/LOG_TA0_921706_01813415.jpg.png","https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A921706/LOG_DE0_921706_01813415.jpg.png"]' href="/aussteller/azure-biosystems/D613959" image-large-bordered="" label-bookmark="Merken" label-bookmarked="Gemerkt" type="Aussteller 2019" url-bookmark="/api/remember/AU_10180047" v-theme="100">
# <template slot="headline">
# <h2 class="t set-300-bold as-headline search-snippet-name">Azure Biosystems</h2>
# <h3 class="t set-040-wide as-copy search-snippet-attribute">Dublin, CA 94568 - USA</h3>
# </template>
# <template slot="content">
# <div class="search-snippet-additional-detail">
# <div class="search-snippet-additional-detail-flex">
# <p class="t set-100-regular as-copy search-snippet-location"></p>
# </div>
# </div>
# </template>
# </o-search-snippet>
# </div>
# <div class="cell small-12">
# <o-search-snippet :divider="true" :image-src='["https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A929036/LOG_MO0_21526_38566_155373740962880000_aeid_60__73_atomfeld_60_73-13142411553737788.jpg.png","https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A929036/LOG_TA0_21526_38566_155373740962880000_aeid_60__73_atomfeld_60_73-13142411553737788.jpg.png","https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A929036/LOG_DE0_21526_38566_155373740962880000_aeid_60__73_atomfeld_60_73-13142411553737788.jpg.png"]' href="/aussteller/baoding-shenchen-precision-pump/N1410043" image-large-bordered="" label-bookmark="Merken" label-bookmarked="Gemerkt" type="Aussteller 2019" url-bookmark="/api/remember/AU_10183334" v-theme="100">
# <template slot="headline">
# <h2 class="t set-300-bold as-headline search-snippet-name">Baoding Shenchen Precision Pump</h2>
# <h3 class="t set-040-wide as-copy search-snippet-attribute">Baoding - CN</h3>
# </template>
# <template slot="content">
# <div class="search-snippet-additional-detail">
# <div class="search-snippet-additional-detail-flex">
# <p class="t set-100-regular as-copy search-snippet-location"></p>
# </div>
# </div>
# </template>
# </o-search-snippet>
# </div>
# <div class="cell small-12">
# <o-search-snippet :divider="true" :image-src='["https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A921708/LOG_MO0_9fc32e9e-1b63-465b-93c6-d0ae8f28b72e_aeid_60__73_atomfeld_60_73-1314271556616661.jpg.png","https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A921708/LOG_TA0_9fc32e9e-1b63-465b-93c6-d0ae8f28b72e_aeid_60__73_atomfeld_60_73-1314271556616661.jpg.png","https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A921708/LOG_DE0_9fc32e9e-1b63-465b-93c6-d0ae8f28b72e_aeid_60__73_atomfeld_60_73-1314271556616661.jpg.png"]' href="/aussteller/beckman-coulter/C499226" image-large-bordered="" label-bookmark="Merken" label-bookmarked="Gemerkt" type="Aussteller 2019" url-bookmark="/api/remember/AU_10180289" v-theme="100">
# <template slot="headline">
# <h2 class="t set-300-bold as-headline search-snippet-name">Beckman Coulter</h2>
# <h3 class="t set-040-wide as-copy search-snippet-attribute">Krefeld - DE</h3>
# </template>
# <template slot="content">
# <p class="t set-200-regular as-copy search-snippet-description">Unternehmensbeschreibung:
# Beckman Coulter, als Teil der Danaher Corporation,  ist einer der weltweit führenden Hersteller von Messinstrumenten und ...</p>
# <div class="search-snippet-additional-detail">
# <div class="search-snippet-additional-detail-flex">
# <p class="t set-100-regular as-copy search-snippet-location"></p>
# </div>
# </div>
# </template>
# </o-search-snippet>
# </div>
# <div class="cell small-12">
# <o-search-snippet :divider="true" :image-src='["/files/files/assets/v3.34.3/assets/content/static/placeholder-exhibitor.png","/files/files/assets/v3.34.3/assets/content/static/placeholder-exhibitor.png","/files/files/assets/v3.34.3/assets/content/static/placeholder-exhibitor.png"]' href="/aussteller/beijing-solarbio-science-tech-/003658" image-large-bordered="" label-bookmark="Merken" label-bookmarked="Gemerkt" type="Aussteller 2019" url-bookmark="/api/remember/AU_10178775" v-theme="100">
# <template slot="headline">
# <h2 class="t set-300-bold as-headline search-snippet-name">Beijing Solarbio Science &amp; Tech.</h2>
# <h3 class="t set-040-wide as-copy search-snippet-attribute">Beijing - CN</h3>
# </template>
# <template slot="content">
# <div class="search-snippet-additional-detail">
# <div class="search-snippet-additional-detail-flex">
# <p class="t set-100-regular as-copy search-snippet-location"></p>
# </div>
# </div>
# </template>
# </o-search-snippet>
# </div>
# <div class="cell small-12">
# <o-search-snippet :divider="true" :image-src='["https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A921710/LOG_MO0_0ca801eb-ab71-4c30-9c67-d8f669d03eb3_aeid_60__73_atomfeld_60_73-1314291554274734.jpg.png","https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A921710/LOG_TA0_0ca801eb-ab71-4c30-9c67-d8f669d03eb3_aeid_60__73_atomfeld_60_73-1314291554274734.jpg.png","https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A921710/LOG_DE0_0ca801eb-ab71-4c30-9c67-d8f669d03eb3_aeid_60__73_atomfeld_60_73-1314291554274734.jpg.png"]' href="/aussteller/berthold-technologies/E336437" image-large-bordered="" label-bookmark="Merken" label-bookmarked="Gemerkt" type="Aussteller 2019" url-bookmark="/api/remember/AU_10180154" v-theme="100">
# <template slot="headline">
# <h2 class="t set-300-bold as-headline search-snippet-name">BERTHOLD TECHNOLOGIES</h2>
# <h3 class="t set-040-wide as-copy search-snippet-attribute">Bad Wildbad - DE</h3>
# </template>
# <template slot="content">
# <p class="t set-200-regular as-copy search-snippet-description">BERTHOLD TECHNOLOGIES - Bioanalytische Messgeräte made in Germany
#
# Berthold Technologies ist ein privat geführter Technologieführer im Bereich Life ...</p>
# <div class="search-snippet-additional-detail">
# <div class="search-snippet-additional-detail-flex">
# <p class="t set-100-regular as-copy search-snippet-location"></p>
# </div>
# </div>
# </template>
# </o-search-snippet>
# </div>
# <div class="cell small-12">
# <o-search-snippet :divider="true" :image-src='["https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A923653/LOG_MO0_21526_38566_155420294282158800_aeid_60__73_atomfeld_60_73-13142221554203546.jpg.png","https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A923653/LOG_TA0_21526_38566_155420294282158800_aeid_60__73_atomfeld_60_73-13142221554203546.jpg.png","https://www.messe.de/apollo/labvolution_2019/obs/Grafik/A923653/LOG_DE0_21526_38566_155420294282158800_aeid_60__73_atomfeld_60_73-13142221554203546.jpg.png"]' href="/aussteller/biametrics/N1404849" image-large-bordered="" label-bookmark="Merken" label-bookmarked="Gemerkt" type="Aussteller 2019" url-bookmark="/api/remember/AU_20174780" v-theme="100">
# <template slot="headline">
# <h2 class="t set-300-bold as-headline search-snippet-name">Biametrics</h2>
# <h3 class="t set-040-wide as-copy search-snippet-attribute">Tübingen - DE</h3>
# </template>
# <template slot="content">
# <p class="t set-200-regular as-copy search-snippet-description">Biametrics bietet Lösungen für Next-generation Microarray Anwendungen. Unsere Technologie ermöglicht das markierungsfreie Screening und die kinetische ...</p>
# <div class="search-snippet-additional-detail">
# <div class="search-snippet-additional-detail-flex">
# <p class="t set-100-regular as-copy search-snippet-location"></p>
# </div>
# </div>
# </template>
# </o-search-snippet>
# </div>
# </template>
# <template slot="footer">
# <div class="cell small-12 search-snippet-list-divider">
# <o-divider v-theme="100">
# </o-divider>
# </div>
# <div class="cell small-12">
# <o-pagination-numeric class="as-center">
# <a class="o button circle as-bordered as-disabled" data-action="page" data-value="0" v-reactive-form.click="">
# <i class="o icon icon-bracket-left"></i>
# </a>
# <a class="o button circle as-active" data-action="page" data-value="1" v-reactive-form.click="">1</a>
# <a class="o button circle" data-action="page" data-value="2" v-reactive-form.click="">2</a>
# <a class="o button circle" data-action="page" data-value="3" v-reactive-form.click="">3</a>
# <span class="t copy as-inline gap">…</span>
# <a class="o button circle as-last" data-action="page" data-value="59" v-reactive-form.click="">59</a>
# <a class="o button circle as-bordered" data-action="page" data-value="2" v-reactive-form.click="">
# <i class="o icon icon-bracket-right"></i>
# </a>
# </o-pagination-numeric>
# </div>
# </template>
# </c-search-snippet-list>
# <input name="state" type="hidden" value="zTnx3oHs35Rd">
# <input name="category" type="hidden" value="ep"/>
# </input></c-search-results>
# <!--index_ignore_end-->
# <!--index_ignore_begin-->
# <!--index_ignore_end-->
# </div>
# <div class="flex-child-shrink">
# <!--index_ignore_begin-->
# <c-toolbar :module-theme="100" v-cloak="">
# <o-toolbar-bookmark-button :bookmarked="0" href="/de/applikation/dashboard/merkliste/#popover-login" tooltip-text="auf der Merkliste" unit-label="Eintrag" units-label="Einträge">
# </o-toolbar-bookmark-button>
# </c-toolbar>
# <c-footer href="https://www.messe.de/" logo-dark="/files/files/assets/v3.34.3/assets/content/static/logo-footer-75-years-de_ci.svg" logo-light="/files/files/assets/v3.34.3/assets/content/static/logo-footer-75-years-de_light.svg" target="_blank" v-cloak="" v-theme="100" v-tracking="{'navi': [['footer/dmag_logo']], 'type': 'event'}">
# <template slot="first-cell">
# <a class="item" href="/de/applikation/formulare/kontakt-allgemein/" v-tracking="{'navi': [['footer/kontakt']], 'type': 'event'}">Kontakt</a>
# <a class="item" href="/de/ueber-uns/presse/" v-tracking="{'navi': [['footer/presse']], 'type': 'event'}">Presse</a>
# <a class="item" href="/de/applikation/registrierung/newsletter/" v-tracking="{'navi': [['footer/newsletter']], 'type': 'event'}">Newsletter</a>
# <a class="item" href="/de/news/mediathek/index-2" v-tracking="{'navi': [['footer/mediathek']], 'type': 'event'}">Mediathek</a>
# </template>
# <template slot="second-cell">
# <a class="item" href="/de/ueber-uns/labvolution/" v-tracking="{'navi': [['footer/labvolution-2023']], 'type': 'event'}">LABVOLUTION 2023</a>
# </template>
# <template slot="third-cell">
# <a class="item" href="/de/deutsche-messe/" v-tracking="{'navi': [['footer/impressum']], 'type': 'event'}">Impressum</a>
# <a class="item" href="/de/deutsche-messe/datenschutz" v-tracking="{'navi': [['footer/datenschutz']], 'type': 'event'}">Datenschutz</a>
# <a class="item" href="/de/deutsche-messe/rechtliche-hinweise" v-tracking="{'navi': [['footer/rechtliche-hinweise']], 'type': 'event'}">Rechtliche Hinweise</a>
# <a class="item" href="/de/deutsche-messe/agb-ticketshop" v-tracking="{'navi': [['footer/agb-ticketshop']], 'type': 'event'}">AGB Ticketshop</a>
# </template>
# <template slot="fair-cell">
# </template>
# <template slot="share-icons">
# <o-share-icons>
# <a href="https://www.facebook.com/labvolution" rel="noopener noreferrer" target="_blank" v-tracking="{'navi': [['footer/social-icon-facebook']], 'type': 'event'}">
# <i class="icon icon-facebook-circle layout-link"></i>
# </a>
# <a href="https://www.linkedin.com/showcase/labvolution" rel="noopener noreferrer" target="_blank" v-tracking="{'navi': [['footer/social-icon-linkedin']], 'type': 'event'}">
# <i class="icon icon-linkedin-circle layout-link"></i>
# </a>
# </o-share-icons>
# </template>
# <template slot="language">
# </template>
# <template slot="hotline">Hotline:</template>
# <template href="tel:+49 (0)511 89-0" slot="hotline-number">+49 (0)511 89-0</template>
# <template slot="messe-name">Deutsche Messe AG</template>
# <template slot="cookie-consent">Cookie Einstellungen</template>
# </c-footer>
# <c-popover :no-use-navigation-bounding="true" class="as-dialog" data-type="c-popover" disable-closer="" id="popover-login" tracking="/tracking" v-cloak="">
# <c-form-login-form :has-login="true" action="/de/loginoverlay" email-label="E-Mail-Adresse" email-name="email" forget-link-href="/de/applikation/login/passwort-vergessen/" forget-link-label="Passwort vergessen?" headline="Login" password-label="Passwort" password-name="password" regist-header="Noch nicht angemeldet?" regist-link-href="/de/applikation/registrierung/account/" regist-link-label="Jetzt registrieren" submit-button-label="Einloggen" v-cloak="" v-theme="100">
# </c-form-login-form>
# </c-popover>
# <c-notifier fixed="bottom" v-cloak="">
# <o-notification button-class-name="notification-browser-button" button-href="https://browser-update.org/de/update.html?force_outdated=true" button-target="_blank" close-control-top-right="" error="" name="browser-notification" session-key="browser-notification" v-cloak="">
# <template slot="content">
# <h3 class="t set-100-bold as-headline">Browser Hinweis</h3>
# <p class="t set-040-wide as-copy">
# <span>Ihr Webbrowser ist veraltet. Aktualisieren Sie Ihren Browser für mehr Sicherheit, Geschwindigkeit und eine optimale Darstellung dieser Seite.</span>
# </p>
# </template>
# <template slot="button">
#                 Browser aktualisieren
#             </template>
# </o-notification>
# </c-notifier>
# <c-overlay :disable-closer="true" v-cloak=""></c-overlay>
# <!--index_ignore_end-->
# </div>
# </div>
# <portal-target name="dialog"></portal-target>
# </main>
# <script client-key="00002971-3e7fd93a-50e4-35ce-a4bf-d0cc619ddf84" container-id="1762" lang="de" src="https://d35ojb8dweouoy.cloudfront.net/loader/loader.js" type="text/javascript">
# </script>
# <script id="emos-settings" type="application/json">{"disabled":false,"pushDisabled":false,"disabledInitializationTracking":false,"disallowedCallers":[],"defaults":{"pageId":"web_1377653_1380069","cmsid":"web_1377653_1380069","siteid":"00079","langid":"de","intern":"web","content":"/de/suche/","search":null},"scriptUrl":"/files/files/assets/v3.34.3/assets/js/emos3.js","mediaScriptUrl":"/files/files/assets/v3.34.3/assets/js/econda-media-minimal.js"}</script>
# <script id="advertisment-settings" type="application/json">
# 		{
# 			"lang": "de",
# 			"default": {
# 				"siteId": "151937",
# 				"pageId": "1074940",
# 				"target": "keyword=null",
# 				"networkid": 1044,
# 				"async": true,
# 				"inSequence": true,
# 				"domain": "//www.smartadserver.com"
# 			},
# 			"scriptURL": "//ced.sascdn.com/tag/1044/smart.js",
# 			"stopAdvertisment": true
# 		}
# 	</script>
# <script defer="" src="/files/files/assets/v3.34.3/assets/js/vendor.js"></script>
# <script defer="" src="/files/files/assets/v3.34.3/assets/js/bootstrap.js"></script>
# <script async="">
# 		document.cookie = `utc_offset=${-new Date().getTimezoneOffset()}`
# 	</script>
# </body>
# </html>
